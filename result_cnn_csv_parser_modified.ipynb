# %%
import pandas as pd

def setup_dataframe(df):
   # df.to_csv('./before.csv')   
   namespace = ['CONV+BN+ELEMWISE', 'NDP_OP', 'BN+ELEMWISE', 'CONV', 'FC', 'POOLING', 'dxCONV', 'dwCONV', 'dxFC', 'dwFC', 'OPT']
   # namespace = ['fusion', 'elementwise', 'GEMM', 'CONV', 'Dgrad', 'Wgrad' ,'others']
   compute_intensives = ['GEMM', 'CONV', 'Wgrad', 'Dgrad']
   df['NAME'] = df['NAME'].replace('fusion.*', 'fusion', regex=True)\
                                       .replace('dgemm', 'dxFC', regex=True)\
                                       .replace('wgemm', 'dwFC', regex=True)\
                                       .replace('.*MetaKernel.*', 'elementwise', regex=True)\
                                       .replace('.*add.*', 'elementwise', regex=True)\
                                       .replace('.*mul.*', 'elementwise', regex=True)\
                                       .replace('.*log.*', 'elementwise', regex=True)\
                                       .replace('.*gemm_.*_tn', 'dxFC', regex=True)\
                                       .replace('.*gemm_.*_nt', 'dwFC', regex=True)\
                                       .replace('.*dgrad.*', 'dxCONV', regex=True)\
                                       .replace('.*wgrad.*', 'dwCONV', regex=True)\
                                       .replace('.*1688cudnn.*', 'CONV+BN+ELEMWISE', regex=True)\
                                       .replace('.*convol.*', 'CONV+BN+ELEMWISE', regex=True)\
                                       .replace('.*gemm_.*', 'FC', regex=True)\
                                       .replace('gemm', 'FC', regex=True)\
                                       .replace('conv', 'CONV', regex=True)\
                                       .replace('.*conv2d.*', 'CONV+BN+ELEMWISE', regex=True)\
                                       .replace('.*first_layer.*', "CONV+BN+ELEMWISE", regex=True)\
                                       .replace('pool', "POOLING", regex=True)\
                                       .replace('.*c1_k1.*', "CONV+BN+ELEMWISE", regex=True)\
                                       .replace('.*bn.*', "BN+ELEMWISE", regex=True)\
                                       .replace('.*adam*', "OPT", regex=True)
                                       # .replace('turing_fp16_s1688gemm_fp16_128x128_ldg8_f2f_tn', 'dxFC', regex=True)\
                                       # .replace('turing_fp16_s1688gemm_fp16_256x128_ldg8_f2f_tn', 'dxFC', regex=True)\
                                       # .replace('turing_fp16_s1688gemm_fp16_256x64_ldg8_f2f_tn', 'dxFC', regex=True)\
                                       # .replace('turing_fp16_s884gemm_fp16_64x64_ldg8_f2f_tn', 'dxFC', regex=True)\
                                       # .replace('turing_fp16_s1688gemm_fp16_128x128_ldg8_f2f_nt', 'dwFC', regex=True)\
                                       # .replace('turing_fp16_s884gemm_fp16_256x128_ldg8_f2f_nt', 'dwFC', regex=True)\
                                       # .replace('turing_fp16_s884gemm_fp16_128x64_ldg8_f2f_nt', 'dwFC', regex=True)\


   # df.to_csv('./test2.csv')
   df['CONFIG'] = df['CONFIG'].replace('V100_downscaled_HBM2_PCI6x1_write_prio_debug', 'NDPX')
   # df['CONFIG'] = df['CONFIG'].replace('V100_downscaled_HBM2_PCI6x1_write_prio', 'NDPX')
   # df['CONFIG'] = df['CONFIG'].replace('V100_downscaled_HBM2_PCI6x1', 'NDPX')
   # df['CONFIG'] = df['CONFIG'].replace('V100_downscaled_HBM2_PCI6x1_baseline', 'NDPX')
                                 
 
   df.loc[~df['NAME'].isin(namespace), 'NAME'] = 'Others'
   df.loc[df['CYCLE'] == '  NOT FOUND', 'CYCLE'] = '0'
   
   
   return df

def setup_dataframe_baseline(df):
   df.to_csv('./before.csv')   
   namespace = ['CONV+BN+ELEMWISE', 'NDP_OP', 'BN+ELEMWISE', 'CONV', 'FC', 'POOLING', 'dxCONV', 'dwCONV', 'dxFC', 'dwFC', 'OPT']
   # namespace = ['fusion', 'elementwise', 'GEMM', 'CONV', 'Dgrad', 'Wgrad' ,'others']
   compute_intensives = ['GEMM', 'CONV', 'Wgrad', 'Dgrad']
   df['NAME'] = df['NAME'].replace('fusion.*', 'fusion', regex=True)\
                                       .replace('dgemm', 'dxFC', regex=True)\
                                       .replace('wgemm', 'dwFC', regex=True)\
                                       .replace('.*MetaKernel.*', 'elementwise', regex=True)\
                                       .replace('.*add.*', 'elementwise', regex=True)\
                                       .replace('.*mul.*', 'elementwise', regex=True)\
                                       .replace('.*log.*', 'elementwise', regex=True)\
                                       .replace('.*gemm_.*_tn', 'dxFC', regex=True)\
                                       .replace('.*gemm_.*_nt', 'dwFC', regex=True)\
                                       .replace('.*dgrad.*', 'dxCONV', regex=True)\
                                       .replace('.*wgrad.*', 'dwCONV', regex=True)\
                                       .replace('.*1688cudnn.*', 'CONV', regex=True)\
                                       .replace('.*convol.*', 'CONV', regex=True)\
                                       .replace('.*gemm_.*', 'FC', regex=True)\
                                       .replace('gemm', 'FC', regex=True)\
                                       .replace('conv', 'CONV', regex=True)\
                                       .replace('.*conv2d.*', 'CONV', regex=True)\
                                       .replace('.*first_layer.*', "CONV", regex=True)\
                                       .replace('pool', "POOLING", regex=True)\
                                       .replace('.*c1_k1.*', "CONV", regex=True)\
                                       .replace('.*bn.*', "BN+ELEMWISE", regex=True)\
                                       .replace('.*adam*', "OPT", regex=True)
                                       # .replace('turing_fp16_s1688gemm_fp16_128x128_ldg8_f2f_tn', 'dxFC', regex=True)\
                                       # .replace('turing_fp16_s1688gemm_fp16_256x128_ldg8_f2f_tn', 'dxFC', regex=True)\
                                       # .replace('turing_fp16_s1688gemm_fp16_256x64_ldg8_f2f_tn', 'dxFC', regex=True)\
                                       # .replace('turing_fp16_s884gemm_fp16_64x64_ldg8_f2f_tn', 'dxFC', regex=True)\
                                       # .replace('turing_fp16_s1688gemm_fp16_128x128_ldg8_f2f_nt', 'dwFC', regex=True)\
                                       # .replace('turing_fp16_s884gemm_fp16_256x128_ldg8_f2f_nt', 'dwFC', regex=True)\
                                       # .replace('turing_fp16_s884gemm_fp16_128x64_ldg8_f2f_nt', 'dwFC', regex=True)\


   # df.to_csv('./test2.csv')

   df['CONFIG'] = df['CONFIG'].replace('V100_downscaled_HBM2_PCI6x1', 'NDPX')
                                 
 
   df.loc[~df['NAME'].isin(namespace), 'NAME'] = 'Others'
   df.loc[df['CYCLE'] == '  NOT FOUND', 'CYCLE'] = '0'
   df.to_csv('./after.csv')
   return df

# %%
import pandas as pd
import gzip
import json
import csv
import re
import pandas as pd
import numpy as np
from tqdm import tqdm 

def parse_name(name):
  name = name.lower()
  name = re.sub(r'[0-9]*', '', name)
  if 'loss' in name or 'entropy' in name:
    return 'Others'
  elif 'optimizer' in name or 'update' in name or 'adam' in name:
    return 'OPT'
  elif 'layernorm' in name or 'layer_norm' in name:
    return 'LayerNorm'
  elif 'batchnorm' in name or 'batch_norm' in name or 'relu' in name:
    return 'BN+ReLU'
  # elif 'cast' in name:
  #   return 'Fusion(Cast)'
  elif 'dropout' in name:
    return 'Dropout'
  elif 'einsum' in name:
    return 'Fusion(Einsum)'
  elif 'biasadd' in name:
    return 'Fusion'
  elif 'gelu' in name:
    return 'Fusion(Gelu)'
  elif 'relu' in name:
    return 'Fusion(ReLU)'
  elif 'self_attention' in name:
    return 'Fusion(SelfAttention)'
  return 'Fusion'

def find_kernel_metadata(name, hlo_file_name):
  if len(name.split('_')) == 1:
    return name
  name = 'fusion.' + name.split('_')[1]
  with open(hlo_file_name, 'r') as f:
    for line in f.readlines():
      if name in line:
        find_meta = line.split('metadata')
        if len(find_meta) > 1 and len(find_meta[1].split('\"')) > 3:
          # print(name, find_meta[1])
          name1 =find_meta[1].split('\"')[3]
          name1 = parse_name(name1)
          return name1
    return 'Fusion'
namespace = ['CONV+BN+ELEMWISE', 'NDP_OP', 'BN+ELEMWISE', 'CONV', 'FC', 'POOLING', 'dxCONV', 'dwCONV', 'dxFC', 'dwFC', 'OPT',\
        'Fusion(Loss)', 'Fusion(Optimizer)', 'Fusion(LayerNorm)','Fusion(BatchNorm)', 'Fusion(Cast)', 'Fusion(Dropout)',\
        'Fusion(Einsum)', 'Fusion(BiasAdd)', 'Fusion(Gelu)', 'Fusion(ReLU)', 'Fusion(SelfAttention)', 'BN+ReLU']
def setup_dataframe(df):
   # df.to_csv('./before.csv')   

   # namespace = ['fusion', 'elementwise', 'GEMM', 'CONV', 'Dgrad', 'Wgrad' ,'others']
   compute_intensives = ['GEMM', 'CONV', 'Wgrad', 'Dgrad']

   df['NAME'] = df['NAME'].replace('.*wgrad2d_c1_k1_nhwc_reduction,*', 'Others', regex=True)

   df['NAME'] = df['NAME'].replace('fusion.*', 'fusion', regex=True)\
                                       .replace('dgemm', 'dxFC', regex=True)\
                                       .replace('wgemm', 'dwFC', regex=True)\
                                       .replace('.*MetaKernel.*', 'elementwise', regex=True)\
                                       .replace('.*add.*', 'elementwise', regex=True)\
                                       .replace('.*mul.*', 'elementwise', regex=True)\
                                       .replace('.*log.*', 'elementwise', regex=True)\
                                       .replace('.*gemm_.*_tn', 'dxFC', regex=True)\
                                       .replace('.*gemm_.*_nt', 'dwFC', regex=True)\
                                       .replace('.*dgrad.*', 'dxCONV', regex=True)\
                                       .replace('.*wgrad.*', 'dwCONV', regex=True)\
                                       .replace('.*1688cudnn.*', 'CONV+BN+ELEMWISE', regex=True)\
                                       .replace('.*convol.*', 'CONV+BN+ELEMWISE', regex=True)\
                                       .replace('.*gemm_.*', 'FC', regex=True)\
                                       .replace('gemm', 'FC', regex=True)\
                                       .replace('conv', 'CONV', regex=True)\
                                       .replace('.*conv2d.*', 'CONV+BN+ELEMWISE', regex=True)\
                                       .replace('.*first_layer.*', "CONV+BN+ELEMWISE", regex=True)\
                                       .replace('pool', "POOLING", regex=True)\
                                       .replace('.*c1_k1.*', "CONV+BN+ELEMWISE", regex=True)\
                                       .replace('.*bn.*', "BN+ELEMWISE", regex=True)\
                                       .replace('.*adam*', "OPT", regex=True)
                                       # .replace('turing_fp16_s1688gemm_fp16_128x128_ldg8_f2f_tn', 'dxFC', regex=True)\
                                       # .replace('turing_fp16_s1688gemm_fp16_256x128_ldg8_f2f_tn', 'dxFC', regex=True)\
                                       # .replace('turing_fp16_s1688gemm_fp16_256x64_ldg8_f2f_tn', 'dxFC', regex=True)\
                                       # .replace('turing_fp16_s884gemm_fp16_64x64_ldg8_f2f_tn', 'dxFC', regex=True)\
                                       # .replace('turing_fp16_s1688gemm_fp16_128x128_ldg8_f2f_nt', 'dwFC', regex=True)\
                                       # .replace('turing_fp16_s884gemm_fp16_256x128_ldg8_f2f_nt', 'dwFC', regex=True)\
                                       # .replace('turing_fp16_s884gemm_fp16_128x64_ldg8_f2f_nt', 'dwFC', regex=True)\
   df.loc[(df['NAME'] == 'CONV+BN+ELEMWISE') & (df['DIRECTION'] == 'backward'), 'NAME'] = 'dxCONV'

   # df.to_csv('./test2.csv')
   df['CONFIG'] = df['CONFIG'].replace('V100_downscaled_HBM2_PCI6x1_write_prio_debug', 'NDPX')
  #  df['CONFIG'] = df['CONFIG'].replace('V100_downscaled_HBM2_PCI6x1_write_prio', 'NDPX')
  #  df['CONFIG'] = df['CONFIG'].replace('V100_downscaled_HBM2_PCI6x1', 'NDPX')
  #  df['CONFIG'] = df['CONFIG'].replace('V100_downscaled_HBM2_PCI6x1_baseline', 'NDPX')
                                 
 
   df.loc[~df['NAME'].isin(namespace), 'NAME'] = 'Others'
   df.loc[df['CYCLE'] == '  NOT FOUND', 'CYCLE'] = '0'
   
   
   return df

def setup_dataframe_baseline(df, hlo_path):
   df.to_csv('./before.csv')   
    # namespace = ['fusion', 'elementwise', 'GEMM', 'CONV', 'Dgrad', 'Wgrad' ,'others']
   compute_intensives = ['GEMM', 'CONV', 'Wgrad', 'Dgrad']
  #  print(df['NAME'])
   fusions = df.loc[df['NAME'].str.contains('fusion')]['NAME']
   for fusion in fusions:
      opname = find_kernel_metadata(fusion, hlo_path)
      # print(fusion, opname)
      df.loc[df['NAME'] == fusion, 'NAME'] = opname

   df['NAME'] = df['NAME'].replace('.*wgrad2d_c1_k1_nhwc_reduction,*', 'Others', regex=True)

   df['NAME'] = df['NAME'].replace('dgemm', 'dxFC', regex=True)\
                                       .replace('wgemm', 'dwFC', regex=True)\
                                       .replace('.*MetaKernel.*', 'elementwise', regex=True)\
                                       .replace('.*add.*', 'elementwise', regex=True)\
                                       .replace('.*mul.*', 'elementwise', regex=True)\
                                       .replace('.*log.*', 'elementwise', regex=True)\
                                       .replace('.*gemm_.*_tn', 'dxFC', regex=True)\
                                       .replace('.*gemm_.*_nt', 'dwFC', regex=True)\
                                       .replace('.*dgrad.*', 'dxCONV', regex=True)\
                                       .replace('.*wgrad.*', 'dwCONV', regex=True)\
                                       .replace('.*1688cudnn.*', 'CONV', regex=True)\
                                       .replace('.*convol.*', 'CONV', regex=True)\
                                       .replace('.*gemm_.*', 'FC', regex=True)\
                                       .replace('gemm', 'FC', regex=True)\
                                       .replace('conv', 'CONV', regex=True)\
                                       .replace('.*conv2d.*', 'CONV', regex=True)\
                                       .replace('.*first_layer.*', "CONV", regex=True)\
                                       .replace('pool', "POOLING", regex=True)\
                                       .replace('.*c1_k1.*', "CONV", regex=True)\
                                       .replace('.*bn.*', "BN+ELEMWISE", regex=True)\
                                       .replace('.*adam*', "OPT", regex=True)
                                       # .replace('turing_fp16_s1688gemm_fp16_128x128_ldg8_f2f_tn', 'dxFC', regex=True)\
                                       # .replace('turing_fp16_s1688gemm_fp16_256x128_ldg8_f2f_tn', 'dxFC', regex=True)\
                                       # .replace('turing_fp16_s1688gemm_fp16_256x64_ldg8_f2f_tn', 'dxFC', regex=True)\
                                       # .replace('turing_fp16_s884gemm_fp16_64x64_ldg8_f2f_tn', 'dxFC', regex=True)\
                                       # .replace('turing_fp16_s1688gemm_fp16_128x128_ldg8_f2f_nt', 'dwFC', regex=True)\
                                       # .replace('turing_fp16_s884gemm_fp16_256x128_ldg8_f2f_nt', 'dwFC', regex=True)\
                                       # .replace('turing_fp16_s884gemm_fp16_128x64_ldg8_f2f_nt', 'dwFC', regex=True)\
   df.loc[(df['NAME'] == 'CONV') & (df['DIRECTION'] == 'backward'), 'NAME'] = 'dxCONV'


   # df.to_csv('./test2.csv')

   df['CONFIG'] = df['CONFIG'].replace('V100_downscaled_HBM2_PCI6x1', 'NDPX')
                                 
 
   df.loc[~df['NAME'].isin(namespace), 'NAME'] = 'Others'
   df.loc[df['CYCLE'] == '  NOT FOUND', 'CYCLE'] = '0'
   df.to_csv('./after.csv')
   return df

# %%
batch_size = [16, 64] # [16,64]
models = ['resnet18', 'resnet50', 'mobilenetv2', 'vgg16']
# models = ['resnet18']
sync = ['sync', 'nosync']
GPUs = [1, 2, 4]
config = 'V100_downscaled_HBM2_PCI6x1_write_prio_debug'

communication_dict = {
   'resnet18-2-nosync': 2814170, 
   'resnet18-4-nosync': 3622957.6,
   'resnet18-8-nosync': 4043382.8,
   'resnet18-2-sync': 2814170 + 555200,
   'resnet18-4-sync': 3622957.6 + 943840,
   'resnet18-8-sync': 4043382.8 + 1887680,
   'resnet50-2-nosync': 5453729.6,
   'resnet50-4-nosync': 7215795.6,
   'resnet50-8-nosync': 8054841.6,
   'resnet50-2-sync': 5453729.6 + 1471280,
   'resnet50-4-sync': 7215795.6 + 2501176,
   'resnet50-8-sync': 8054841.6 + 5002352,
   'mobilenetv2-2-nosync': 905114.8,
   'mobilenetv2-4-nosync': 1135800.4,
   'mobilenetv2-2-sync': 905114.8 + 1443520,
   'mobilenetv2-4-sync': 1135800.4 + 2453984,
   'vgg16-2-nosync': 28906152,
   'vgg16-4-nosync': 39120444,
   'vgg16-2-sync': 28906152 + 347880,
   'vgg16-4-sync': 39120444 + 591396
}



for model in models:
   for b in batch_size:
      # if model == 'resnet50' and b == 64:
      #    continue
      if model == 'vgg16' and b == 64:
         b = 32
      file_paths = []
      baseline_home='/home/shared/CXL_memory_buffer/BASELINE_ISCA/csv_files/'
      baseline_path=baseline_home+model+'_baseline_batch_'+str(b)+'-V100_downscaled_HBM2_PCI6x1_write_prio_debug.csv'
      baseline_bw_path=baseline_home+model+'_baseline_batch_'+str(b)+'-V100_downscaled_HBM2_PCI6x1_write_prio_debug-bw.csv'
      file_paths.append(baseline_path)
      file_paths.append(baseline_bw_path)
      baseline_path=baseline_home+model+'_baseline_batch_'+str(b)+'-V100_downscaled_HBM2_PCI6x1_write_prio_debug_additional_sm.csv'
      baseline_bw_path=baseline_home+model+'_baseline_batch_'+str(b)+'-V100_downscaled_HBM2_PCI6x1_write_prio_debug_additional_sm-bw.csv'
      file_paths.append(baseline_path)
      file_paths.append(baseline_bw_path)
      baseline_path=baseline_home+model+'_baseline_batch_'+str(b)+'-V100_downscaled_HBM2_PCI6x1_write_prio_debug_additional_mem.csv'
      baseline_bw_path=baseline_home+model+'_baseline_batch_'+str(b)+'-V100_downscaled_HBM2_PCI6x1_write_prio_debug_additional_mem-bw.csv'
      file_paths.append(baseline_path)
      file_paths.append(baseline_bw_path)
      baseline_path=baseline_home+model+'_baseline_batch_'+str(b)+'-V100_downscaled_HBM2_PCI6x1_write_prio_debug_additional_hw.csv'
      baseline_bw_path=baseline_home+model+'_baseline_batch_'+str(b)+'-V100_downscaled_HBM2_PCI6x1_write_prio_debug_additional_hw-bw.csv'
      file_paths.append(baseline_path)
      file_paths.append(baseline_bw_path)
      # file_paths.append(baseline2xmem_path)
      for GPU in GPUs:
         for s in sync:
            if GPU == 1 and s == 'sync':
               continue
            temp = 1
            if GPU == 8:
               temp = 8
            ndp_csv_home='/home/shared/CXL_memory_buffer/NDP_ISCA/csv_files/'
            file_path=ndp_csv_home+model+'_ndp_batch_'+str(b)+'-'+config+'-'+str(GPU)+'-'+s+'.csv'
            file_path_bw=ndp_csv_home+model+'_ndp_batch_'+str(b)+'-'+config+'-'+str(GPU)+'-'+s+'-bw.csv'
            # file_path=ndp_csv_home+model+'_ndp_batch_'+str(b)+'-'+config+'-'+str(GPU)+'-'+s+'.csv'
            # file_path_bw=ndp_csv_home+model+'_ndp_batch_'+str(b)+'-'+config+'-'+str(GPU)+'-'+s+'-bw.csv'
            file_paths.append(file_path)
            file_paths.append(file_path_bw)

      baseline0 = pd.read_csv(file_paths[0])
      baseline0['GPUS'] = '1_GPU'
      baseline0['CONFIG'] = 'BASELINE'
      baseline1 = pd.read_csv(file_paths[1])
      baseline1['GPUS'] = '1_GPU'
      baseline1['CONFIG'] = 'BASELINE'

      baseline2 = pd.read_csv(file_paths[2])
      baseline2['GPUS'] = '1_GPU'
      baseline2['CONFIG'] = 'BASELINE_sm'
      baseline3 = pd.read_csv(file_paths[3])
      baseline3['GPUS'] = '1_GPU'
      baseline3['CONFIG'] = 'BASELINE_sm'

      baseline4 = pd.read_csv(file_paths[4])
      baseline4['GPUS'] = '1_GPU'
      baseline4['CONFIG'] = 'BASELINE_mem'
      baseline5 = pd.read_csv(file_paths[5])
      baseline5['GPUS'] = '1_GPU'
      baseline5['CONFIG'] = 'BASELINE_mem'

      baseline6 = pd.read_csv(file_paths[6])
      baseline6['GPUS'] = '1_GPU'
      baseline6['CONFIG'] = 'BASELINE_both'
      baseline7 = pd.read_csv(file_paths[7])
      baseline7['GPUS'] = '1_GPU'
      baseline7['CONFIG'] = 'BASELINE_both'

      # print('file_paths:',file_paths)
      ndpx = pd.read_csv(file_paths[8])
      if 'nosync' in file_paths[8]:
         ndpx['SYNC'] ='BN'
      else:
         ndpx['SYNC'] = 'syncBN'
      # ndpx['GPUS'] = file_paths[8].split('-')[-3]+'_GPU'
      ndpx['GPUS'] = file_paths[8].split('-')[-2]+'_GPU'
      for ndp_csv in file_paths[9:]:
         # print(ndp_csv)
         temp = pd.read_csv(ndp_csv)
         if 'nosync' in ndp_csv:
            temp['SYNC'] ='BN'
         else:
            temp['SYNC'] = 'syncBN'
         if 'bw' in ndp_csv.split('-')[-1]:
            print(ndp_csv)
            # temp['GPUS'] = ndp_csv.split('-')[-4]+'_GPU'
            temp['GPUS'] = ndp_csv.split('-')[-3]+'_GPU'
         else:
            # temp['GPUS'] = ndp_csv.split('-')[-3]+'_GPU'
            temp['GPUS'] = ndp_csv.split('-')[-2]+'_GPU'
         # print(ndp_csv)
         # print(ndp_csv.split('-')[-2])
         ndpx = pd.concat([ndpx, temp])
      # ndpx.to_csv('./'+model+'/ndpx'+str(b)+'.csv')

      # df = setup_dataframe_baseline(baseline0.loc[baseline0['DIRECTION'] =='forward'])
      baseline_hlp_path=baseline_home+'xla_hlo/'+model+'_baseline_batch_'+str(b)+'.txt'
      df = setup_dataframe_baseline(pd.concat([baseline0, baseline1]), baseline_hlp_path)

      # df = df.loc[df['DIRECTION'] == 'forward']
      baseline_runtime = pd.to_numeric(df['CYCLE']).sum()
      df = pd.concat([df, setup_dataframe_baseline(pd.concat([baseline2, baseline3, baseline4, baseline5, baseline6, baseline7]), baseline_hlp_path)])

      # df = pd.concat([df, setup_dataframe(baseline1.loc[baseline1['DIRECTION'] == 'forward'])])
      # df = df.loc[df['DIRECTION'] == 'forward']
      df['SYNC'] = 'BN'

      original_df = df.copy()
      for g in GPUs:
         if g == 1:
            continue
         for s in sync:
            communication_key = model+'-'+str(g)+'-'+s
            communication_overhead = communication_dict[communication_key]
            new_baseline = original_df.copy()
            new_baseline['GPUS'] = str(g)+'_GPU'
            configs = ['BASELINE', 'BASELINE_sm', 'BASELINE_mem', 'BASELINE_both']
            if s == 'sync':
               s = 'syncBN'
            else:
               s = 'BN'
            new_baseline['SYNC'] = s
            for c in configs:
               all_reduce = {'GPUS': str(g)+'_GPU', 'CONFIG': c, 'DIRECTION': 'backward', 'NAME': 'All-reduce', 'CYCLE': str(communication_overhead), 'SYNC': s}
               new_baseline = new_baseline.append(all_reduce, ignore_index=True)
            df = pd.concat([df, new_baseline])
         # df.to_csv('temp.csv')
         # assert(False)

         

      df = pd.concat([df, setup_dataframe(ndpx)])
      # df = df.loc[df['DIRECTION'] == 'forward']
      df['CYCLE'] = pd.to_numeric(df['CYCLE'])
      grouped = df.groupby(['CONFIG','GPUS','SYNC','NAME']).sum()[[ 'CYCLE']]

      grouped['BATCH SIZE'] = 'BATCH '+str(b)
      # grouped['DIRECTION'] = 'Forward'
      grouped['MODEL'] = model
      # print(grouped)
      # grouped['CONFIG'] = grouped['CONFIG'].replace('NDPX', 'NDPX_ISCA') \
      #    .replace('NDPX_baseline_64', 'NDPX')
      grouped.to_csv('./'+model+'/total_value'+str(b)+'.csv')
      normalized = grouped
      normalized['CYCLE'] = grouped['CYCLE'] / baseline_runtime
      normalized.to_csv('./'+model+'/total_normalized'+str(b)+'.csv')
# Out:
# /home/shared/CXL_memory_buffer/NDP_ISCA/csv_files/resnet18_ndp_batch_16-V100_downscaled_HBM2_PCI6x1_write_prio_debug-1-nosync-bw.csv
# /home/shared/CXL_memory_buffer/NDP_ISCA/csv_files/resnet18_ndp_batch_16-V100_downscaled_HBM2_PCI6x1_write_prio_debug-2-sync-bw.csv
# /home/shared/CXL_memory_buffer/NDP_ISCA/csv_files/resnet18_ndp_batch_16-V100_downscaled_HBM2_PCI6x1_write_prio_debug-2-nosync-bw.csv
# /home/shared/CXL_memory_buffer/NDP_ISCA/csv_files/resnet18_ndp_batch_16-V100_downscaled_HBM2_PCI6x1_write_prio_debug-4-sync-bw.csv
# /home/shared/CXL_memory_buffer/NDP_ISCA/csv_files/resnet18_ndp_batch_16-V100_downscaled_HBM2_PCI6x1_write_prio_debug-4-nosync-bw.csv
# /home/shared/CXL_memory_buffer/NDP_ISCA/csv_files/resnet18_ndp_batch_64-V100_downscaled_HBM2_PCI6x1_write_prio_debug-1-nosync-bw.csv
# /home/shared/CXL_memory_buffer/NDP_ISCA/csv_files/resnet18_ndp_batch_64-V100_downscaled_HBM2_PCI6x1_write_prio_debug-2-sync-bw.csv
# ...

# %%
# hhk971

batch_size = [64] # [16,64]
# models = ['resnet18', 'resnet50', 'mobilenetv2']
models = [ 'resnet50']
# models = ['resnet18']
# models = ['vgg16']
sync = ['nosync']
GPUs = [1, 2]
# config = 'V100_downscaled_HBM2_PCI6x1_write_prio_debug'

communication_dict = {
   'resnet18-2-nosync': 2547561.38, 
   'resnet18-4-nosync': 3822200.15, 
   'resnet18-8-nosync': 4461670.92,
   'resnet18-2-sync': 2814170 + 555200,
   'resnet18-4-sync': 3622957.6 + 943840,
   'resnet18-8-sync': 4043382.8 + 1887680,
   'resnet50-2-nosync': 5203502.31,
   'resnet50-4-nosync': 7806111.54,
   'resnet50-8-nosync': 8054841.6,
   'resnet50-2-sync': 5453729.6 + 1471280,
   'resnet50-4-sync': 7215795.6 + 2501176,
   'resnet50-8-sync': 8054841.6 + 5002352,
   'mobilenetv2-2-nosync': 753646.308,
   'mobilenetv2-4-nosync': 1131497.38,
   'mobilenetv2-8-nosync': 1562888,
   'mobilenetv2-2-sync': 905114.8 + 1443520,
   'mobilenetv2-4-sync': 1135800.4 + 2453984,
   'vgg16-2-nosync': 30614525.1,
   'vgg16-4-nosync': 45922645.7,
   'vgg16-8-nosync': 44746734,
   'vgg16-2-sync': 28906152 + 347880,
   'vgg16-4-sync': 39120444 + 591396
}



for model in models:
   for b in batch_size:
      if model == 'vgg16' and b == 64:
         b = 32
      file_paths = []
      baseline_home='/home/shared/CXL_memory_buffer/BASELINE_ISCA/csv_files/'
      # baseline_path=baseline_home+model+'_baseline_batch_'+str(b)+'-V100_downscaled_HBM2_PCI6x1_write_prio_debug.csv'
      # baseline_bw_path=baseline_home+model+'_baseline_batch_'+str(b)+'-V100_downscaled_HBM2_PCI6x1_write_prio_debug-bw.csv'
      # file_paths.append(baseline_path)
      # file_paths.append(baseline_bw_path)
      baseline_path=baseline_home+model+'_baseline_batch_'+str(b)+'-NDPX_baseline_64.csv'
      baseline_bw_path=baseline_home+model+'_baseline_batch_'+str(b)+'-NDPX_baseline_64-bw.csv'
      file_paths.append(baseline_path)
      file_paths.append(baseline_bw_path)
      baseline_path=baseline_home+model+'_baseline_batch_'+str(b)+'-NDPX_baseline_64_no_hash.csv'
      baseline_bw_path=baseline_home+model+'_baseline_batch_'+str(b)+'-NDPX_baseline_64_no_hash-bw.csv'
      file_paths.append(baseline_path)
      file_paths.append(baseline_bw_path)
      baseline_path=baseline_home+model+'_baseline_batch_'+str(b)+'-NDPX_baseline_64_2bit_hash.csv'
      
      file_paths.append(baseline_path)
      
      # baseline_path=baseline_home+model+'_baseline_batch_'+str(b)+'_l1hit-NDPX_baseline_64_l1hit.csv'
      # baseline_bw_path=baseline_home+model+'_baseline_batch_'+str(b)+'_l1hit-NDPX_baseline_64_l1hit-bw.csv'
      # file_paths.append(baseline_path)
      # file_paths.append(baseline_bw_path)
      # print(file_paths)
      
      
      for g in GPUs:
         for s in sync:
            if g == 1 and s == 'sync':
               continue
            ndp_csv_home='/home/shared/CXL_memory_buffer/NDP_ISCA/csv_files/'
            config = 'NDPX_baseline_64'
            file_path=ndp_csv_home+'new_'+model+'_ndp_batch_'+str(b)+'-'+config+'-'+str(g)+'-'+str(g)+'-'+s+'.csv'
            file_path_bw=ndp_csv_home+'new_'+model+'_ndp_batch_'+str(b)+'-'+config+'-'+str(g)+'-'+str(g)+'-'+s+'-bw.csv'
            file_paths.append(file_path)
            file_paths.append(file_path_bw)
            config = 'GPU_NDPX_ipoly'
            file_path=ndp_csv_home+'new_'+model+'_ndp_batch_'+str(b)+'-'+config+'-'+str(g)+'-'+str(g)+'-sync.csv'
            file_path_bw=ndp_csv_home+'new_'+model+'_ndp_batch_'+str(b)+'-'+config+'-'+str(g)+'-'+str(g)+'-sync-bw.csv'
            file_paths.append(file_path)
            file_paths.append(file_path_bw)
            # file_path=ndp_csv_home+''+model+'_ndp_batch_'+str(b)+'_l2-'+config+'-'+str(g)+'-'+str(g)+'-sync.csv'
            # file_path_bw=ndp_csv_home+''+model+'_ndp_batch_'+str(b)+'_l2-'+config+'-'+str(g)+'-'+str(g)+'-sync-bw.csv'
            # file_paths.append(file_path)
            # file_paths.append(file_path_bw)
            # file_path=ndp_csv_home+''+model+'_ndp_batch_'+str(b)+'_l2_infQ-'+config+'-'+str(g)+'-'+str(g)+'-sync.csv'
            # file_path_bw=ndp_csv_home+''+model+'_ndp_batch_'+str(b)+'_l2_infQ-'+config+'-'+str(g)+'-'+str(g)+'-sync-bw.csv'
            # file_paths.append(file_path)
            # file_paths.append(file_path_bw)
            # file_path=ndp_csv_home+''+model+'_ndp_batch_'+str(b)+'_l2_infQ_2xInstQ-'+config+'-'+str(g)+'-'+str(g)+'-sync.csv'
            # file_path_bw=ndp_csv_home+''+model+'_ndp_batch_'+str(b)+'_l2_infQ_2xInstQ-'+config+'-'+str(g)+'-'+str(g)+'-sync-bw.csv'
            # file_paths.append(file_path)
            # file_paths.append(file_path_bw)
            # config = 'GPU_NDPX_2xinstQ_128Kreg'
            # file_path=ndp_csv_home+''+model+'_ndp_batch_'+str(b)+'_l2_infQ-'+config+'-'+str(g)+'-'+str(g)+'-sync.csv'
            # file_path_bw=ndp_csv_home+''+model+'_ndp_batch_'+str(b)+'_l2_infQ-'+config+'-'+str(g)+'-'+str(g)+'-sync-bw.csv'
            # file_paths.append(file_path)
            # file_paths.append(file_path_bw)
            # config = 'GPU_NDPX_4xinstQ_128Kreg'
            # file_path=ndp_csv_home+''+model+'_ndp_batch_'+str(b)+'_l2_infQ-'+config+'-'+str(g)+'-'+str(g)+'-sync.csv'
            # file_path_bw=ndp_csv_home+''+model+'_ndp_batch_'+str(b)+'_l2_infQ-'+config+'-'+str(g)+'-'+str(g)+'-sync-bw.csv'
            # file_paths.append(file_path)
            # file_paths.append(file_path_bw)
            # config = 'GPU_NDPX_16xinstQ_128Kreg'
            # file_path=ndp_csv_home+''+model+'_ndp_batch_'+str(b)+'_l2_infQ-'+config+'-'+str(g)+'-'+str(g)+'-sync.csv'
            # file_path_bw=ndp_csv_home+''+model+'_ndp_batch_'+str(b)+'_l2_infQ-'+config+'-'+str(g)+'-'+str(g)+'-sync-bw.csv'
            # file_paths.append(file_path)
            # file_paths.append(file_path_bw)
            # for i in [2,4,8]:
            #    file_path=ndp_csv_home+'new_'+model+'_ndp_batch_'+str(b)+'-'+config+'_'+str(i)+'xlink-'+str(g)+'-'+str(g)+'-'+s+'.csv'
            #    file_path_bw=ndp_csv_home+'new_'+model+'_ndp_batch_'+str(b)+'-'+config+'_'+str(i)+'xlink-'+str(g)+'-'+str(g)+'-'+s+'-bw.csv'
            #    file_paths.append(file_path)
            #    file_paths.append(file_path_bw)

      baseline0 = pd.read_csv(file_paths[0])
      baseline0['GPUS'] = '1_GPU'
      baseline0['CONFIG'] = 'BASELINE'
      baseline1 = pd.read_csv(file_paths[1])
      baseline1['GPUS'] = '1_GPU'
      baseline1['CONFIG'] = 'BASELINE'

      baseline2 = pd.read_csv(file_paths[2])
      baseline2['GPUS'] = '1_GPU'
      baseline2['CONFIG'] = 'BASELINE_no_hash'
      baseline3 = pd.read_csv(file_paths[3])
      baseline3['GPUS'] = '1_GPU'
      baseline3['CONFIG'] = 'BASELINE_no_hash'

      baseline4 = pd.read_csv(file_paths[4])
      baseline4['GPUS'] = '1_GPU'
      baseline4['CONFIG'] = 'BASELINE_2bit_hash'



      baseline_hlp_path=baseline_home+'xla_hlo/'+model+'_baseline_batch_'+str(b)+'.txt'
      df = setup_dataframe_baseline(baseline0, baseline_hlp_path)
      
      # df = df.loc[df['DIRECTION'] == 'forward']

      baseline_runtime = pd.to_numeric(df['CYCLE']).sum()
      print(file_paths[2])
      df = pd.concat([df, setup_dataframe_baseline(baseline2, baseline_hlp_path)])
      df = pd.concat([df, setup_dataframe_baseline(baseline4, baseline_hlp_path)])
      df['SYNC'] = 'BN'
      df.to_csv(f'{model}_{b}_baseline_lable.csv', index=False)

      original_df = df.copy()

      ndpx = pd.read_csv(file_paths[5])
      if 'nosync' in file_paths[5]:
         ndpx['SYNC'] ='BN'
      else:
         ndpx['SYNC'] = 'syncBN'
      ndpx['GPUS'] = file_paths[5].split('-')[-3]+'_GPU'
      if 'V100' in file_paths[5].split('-')[-3]:
         ndpx['GPUS'] = file_paths[5].split('-')[-2]+'_GPU'
      # ndpx['GPUS'] = file_paths[8].split('-')[-2]+'_GPU'
      for ndp_csv in file_paths[6:]:
         print(ndp_csv)
         temp = pd.read_csv(ndp_csv)
         if 'nosync' in ndp_csv:
            temp['SYNC'] ='BN'
         else:
            temp['SYNC'] = 'syncBN'
         if 'bw' in ndp_csv.split('-')[-1]:
            # print(ndp_csv)
            temp['GPUS'] = ndp_csv.split('-')[-4]+'_GPU'
            if 'V100' in ndp_csv.split('-')[-4]:
               temp['GPUS'] = ndp_csv.split('-')[-3]+'_GPU'
         else:
            temp['GPUS'] = ndp_csv.split('-')[-3]+'_GPU'
            if 'V100' in ndp_csv.split('-')[-3]+'_GPU':
               temp['GPUS'] = ndp_csv.split('-')[-2]+'_GPU'
         # if 'l2-GPU' in ndp_csv:
         #    temp['CONFIG'] = 'GPU_NDP_bypass_L2'
         # eli
         if 'l2_infQ_2xInstQ' in ndp_csv:
            temp['CONFIG'] = 'GPU_NDP_bypass_L2_infinity_Queue_2xInstQ'
         elif 'l2_infQ-' in ndp_csv:
            temp['CONFIG'] = 'GPU_NDP_bypass_L2_infinity_Queue'
      
         # print(ndp_csv)
         ndpx = pd.concat([ndpx, temp])
         # if ndp_csv == file_paths[3]:
            # setup_dataframe(ndpx).to_csv(f'{model}_{b}_ndpx_lable.csv', index=False)
      print(ndpx)
      df = pd.concat([df, setup_dataframe(ndpx)])
      df['CYCLE'] = pd.to_numeric(df['CYCLE'])
      df.to_csv('temp1.csv')
      # df = df.loc[df['DIRECTION'] == 'forward']
      grouped = df.groupby(['CONFIG','GPUS','SYNC','NAME']).sum()[[ 'CYCLE']]
      
      grouped['BATCH SIZE'] = 'Batch '+str(b)
      grouped['MODEL'] = model
      grouped['MODEL'] = grouped['MODEL'].replace('new_', '', regex=True) \
         .replace('resnet', 'ResNet-', regex=True) \
         .replace('mobilenetv2', 'MobileNetv2') \
         .replace('vgg16', 'VGG-16')
      grouped.to_csv('temp2.csv')
      grouped.to_csv('./'+model+'/total_value'+str(b)+'.csv')
      normalized = grouped
      normalized['CYCLE'] = grouped['CYCLE'] / baseline_runtime
      normalized.to_csv('./'+model+'/total_normalized'+str(b)+'.csv')
# Out:
# /home/shared/CXL_memory_buffer/BASELINE_ISCA/csv_files/resnet18_baseline_batch_16-NDPX_baseline_64_no_hash.csv
# /home/shared/CXL_memory_buffer/NDP_ISCA/csv_files/new_resnet18_ndp_batch_16-NDPX_baseline_64-1-1-nosync-bw.csv
# /home/shared/CXL_memory_buffer/NDP_ISCA/csv_files/new_resnet18_ndp_batch_16-GPU_NDPX_ipoly-1-1-sync.csv
# /home/shared/CXL_memory_buffer/NDP_ISCA/csv_files/new_resnet18_ndp_batch_16-GPU_NDPX_ipoly-1-1-sync-bw.csv
#       GPUS            CONFIG    SYNC    ID DIRECTION  \
# 0    1_GPU  NDPX_baseline_64      BN  2570   forward
# 1    1_GPU  NDPX_baseline_64      BN  2570   forward
# 2    1_GPU  NDPX_baseline_64      BN  2571   forward
# 3    1_GPU  NDPX_baseline_64      BN  2571   forward
# 4    1_GPU  NDPX_baseline_64      BN  2572   forward
# ..     ...               ...     ...   ...       ...
# 295  1_GPU    GPU_NDPX_ipoly  syncBN  2816  backward
# 296  1_GPU    GPU_NDPX_ipoly  syncBN  2817  backward
# 297  1_GPU    GPU_NDPX_ipoly  syncBN  2817  backward
# ...

# %%
batch_size = [64] # [16,64]
models = ['resnet18', 'resnet50', 'mobilenetv2', 'vgg16']
# models = ['resnet18', 'mobilenetv2']
# models = ['resnet50']
# models = ['vgg16']
sync = ['nosync']
GPUs = [1]
# config = 'V100_downscaled_HBM2_PCI6x1_write_prio_debug'

communication_dict = {
   'resnet18-2-nosync': 2814170, 
   'resnet18-4-nosync': 3622957.6,
   'resnet18-8-nosync': 4043382.8,
   'resnet18-2-sync': 2814170 + 555200,
   'resnet18-4-sync': 3622957.6 + 943840,
   'resnet18-8-sync': 4043382.8 + 1887680,
   'resnet50-2-nosync': 5453729.6,
   'resnet50-4-nosync': 7215795.6,
   'resnet50-8-nosync': 8054841.6,
   'resnet50-2-sync': 5453729.6 + 1471280,
   'resnet50-4-sync': 7215795.6 + 2501176,
   'resnet50-8-sync': 8054841.6 + 5002352,
   'mobilenetv2-2-nosync': 905114.8,
   'mobilenetv2-4-nosync': 1135800.4,
   'mobilenetv2-8-nosync': 1562888,
   'mobilenetv2-2-sync': 905114.8 + 1443520,
   'mobilenetv2-4-sync': 1135800.4 + 2453984,
   'vgg16-2-nosync': 28906152,
   'vgg16-4-nosync': 39120444,
   'vgg16-8-nosync': 44746734,
   'vgg16-2-sync': 28906152 + 347880,
   'vgg16-4-sync': 39120444 + 591396
}



for model in models:
   for b in batch_size:
      if model == 'vgg16' and b == 64:
         b = 32
      file_paths = []
      baseline_home='/home/shared/CXL_memory_buffer/BASELINE_ISCA/csv_files/'
      baseline_path=baseline_home+model+'_baseline_batch_'+str(b)+'-NDPX_baseline_64.csv'
      baseline_bw_path=baseline_home+model+'_baseline_batch_'+str(b)+'-NDPX_baseline_64-bw.csv'
      file_paths.append(baseline_path)
      file_paths.append(baseline_bw_path)
      baseline_path=baseline_home+model+'_baseline_batch_'+str(b)+'_l1hit-NDPX_baseline_64_l1hit.csv'
      baseline_bw_path=baseline_home+model+'_baseline_batch_'+str(b)+'_l1hit-NDPX_baseline_64_l1hit-bw.csv'
      file_paths.append(baseline_path)
      file_paths.append(baseline_bw_path)
      # print(file_paths)
      for g in GPUs:
         for s in sync:
            if g == 1 and s == 'sync':
               continue
            ndp_csv_home = f'/home/shared/CXL_memory_buffer/NDP_ISCA/csv_files/'
            config = 'GPU-NDP_1GH_NDP'
            file_path=ndp_csv_home+''+model+'_ndp_batch_'+str(b)+'_opt-'+config+'-'+str(g)+'-'+str(g)+'-'+s+'.csv'
            file_path_bw=ndp_csv_home+''+model+'_ndp_batch_'+str(b)+'_opt-'+config+'-'+str(g)+'-'+str(g)+'-'+s+'-bw.csv'
            file_paths.append(file_path)
            file_paths.append(file_path_bw)
            config = 'GPU-NDP_3GH_NDP'
            file_path=ndp_csv_home+''+model+'_ndp_batch_'+str(b)+'_opt-'+config+'-'+str(g)+'-'+str(g)+'-'+s+'.csv'
            file_path_bw=ndp_csv_home+''+model+'_ndp_batch_'+str(b)+'_opt-'+config+'-'+str(g)+'-'+str(g)+'-'+s+'-bw.csv'
            file_paths.append(file_path)
            file_paths.append(file_path_bw)
            # config = 'GPU-NDP_NDP_first'
            # file_path=ndp_csv_home+''+model+'_ndp_batch_'+str(b)+'_opt-'+config+'-'+str(g)+'-'+str(g)+'-'+s+'.csv'
            # file_path_bw=ndp_csv_home+''+model+'_ndp_batch_'+str(b)+'_opt-'+config+'-'+str(g)+'-'+str(g)+'-'+s+'-bw.csv'
            # file_paths.append(file_path)
            # file_paths.append(file_path_bw)
            # config = 'NDPX_baseline_64_2xlink'
            # file_path=ndp_csv_home+'new_'+model+'_ndp_batch_'+str(b)+'-'+config+'-'+str(g)+'-'+str(g)+'-'+s+'.csv'
            # file_path_bw=ndp_csv_home+'new_'+model+'_ndp_batch_'+str(b)+'-'+config+'-'+str(g)+'-'+str(g)+'-'+s+'-bw.csv'
            # for ss in ['PCM_slc', '0.5xmem', '2xmem']:
            #    config = f'NDPX_baseline_64_2xlink_{ss}'
            #    file_path=ndp_csv_home+'new_'+model+'_ndp_batch_'+str(b)+'-'+config+'-'+str(g)+'-'+str(g)+'-'+s+'.csv'
            #    file_path_bw=ndp_csv_home+'new_'+model+'_ndp_batch_'+str(b)+'-'+config+'-'+str(g)+'-'+str(g)+'-'+s+'-bw.csv'
            #    file_paths.append(file_path)
            #    file_paths.append(file_path_bw)
            # if g == 4:            
            #    file_path=ndp_csv_home+'new_'+model+'_ndp_batch_80-'+config+'-'+str(g)+'-'+str(g)+'-'+s+'.csv'
            #    file_path_bw=ndp_csv_home+'new_'+model+'_ndp_batch_80-'+config+'-'+str(g)+'-'+str(g)+'-'+s+'-bw.csv'
            #    file_paths.append(file_path)
            #    file_paths.append(file_path_bw)
      baseline0 = pd.read_csv(file_paths[0])
      baseline0['GPUS'] = '1_GPU'
      baseline0['CONFIG'] = 'BASELINE'
      baseline1 = pd.read_csv(file_paths[1])
      baseline1['GPUS'] = '1_GPU'
      baseline1['CONFIG'] = 'BASELINE'
      print(file_paths[2])
      baseline2 = pd.read_csv(file_paths[2])
      baseline2['GPUS'] = '1_GPU'
      baseline2['CONFIG'] = 'BASELINE_fused'
      # baseline3 = pd.read_csv(file_paths[3])
      # baseline3['GPUS'] = '1_GPU'
      # baseline3['CONFIG'] = 'BASELINE_additional_SM'


      baseline_hlp_path=baseline_home+'xla_hlo/'+model+'_baseline_batch_'+str(b)+'.txt'
      df = setup_dataframe_baseline(baseline0, baseline_hlp_path)
      baseline_convs = df.loc[df['NAME'] == 'CONV']
      baseline_convs.to_csv('baseline_convs.csv')
      baseline_runtime = pd.to_numeric(df['CYCLE']).sum()
      # print(file_paths[2])
      df = pd.concat([df, setup_dataframe_baseline(baseline2, baseline_hlp_path)])
      df['SYNC'] = 'BN'

      df.to_csv('temp.csv')
      original_df = df.copy()
      for g in GPUs:
         if g == 1:
            continue
         for s in sync:
            df_multi_GPU = original_df.copy()
            df_multi_GPU['GPUS'] = f'{g}_GPU'        
            df_multi_GPU['SYNC'] = 'BN' if s == 'nosync' else 'syncBN'
            communication_key = model+'-'+str(g)+'-'+s
            communication_overhead = communication_dict[communication_key]
            all_reduce = {'GPUS': str(g)+'_GPU', 'CONFIG': 'BASELINE', 'DIRECTION': 'backward', 'NAME': 'All-reduce', 'CYCLE': str(communication_overhead), 'SYNC': 'BN' if s == 'nosync' else 'syncBN'}
            df_multi_GPU = df_multi_GPU.append(all_reduce, ignore_index=True)
            df = pd.concat([df, df_multi_GPU])

      ndp_start_index = 4
      # print(file_paths)
      ndpx = pd.read_csv(file_paths[ndp_start_index])
      if 'nosync' in file_paths[ndp_start_index]:
         ndpx['SYNC'] ='BN'
      else:
         ndpx['SYNC'] = 'syncBN'
      ndpx['GPUS'] = file_paths[ndp_start_index].split('-')[-3]+'_GPU'
      for ndp_csv in file_paths[ndp_start_index+1:]:
         print(ndp_csv)
         temp = pd.read_csv(ndp_csv)
         if 'nosync' in ndp_csv:
            temp['SYNC'] ='BN'
         else:
            temp['SYNC'] = 'syncBN'
         if 'bw' in ndp_csv.split('-')[-1]:
            # print(ndp_csv)
            temp['GPUS'] = ndp_csv.split('-')[-4]+'_GPU'
         else:
            temp['GPUS'] = ndp_csv.split('-')[-3]+'_GPU'
         # print(ndp_csv)
         ndpx = pd.concat([ndpx, temp])

      ndp_frame = setup_dataframe(ndpx)
      ndp_frame.to_csv('ndp.csv')
      # ndp_convs = ndp_frame.loc[ndp_frame['NAME'] == 'CONV+BN+ELEMWISE']
      # ndp_convs.to_csv('ndp_convs.csv')

      df = pd.concat([df, ndp_frame])

      df['CYCLE'] = pd.to_numeric(df['CYCLE'])
      df.to_csv('temp1.csv')
      
      # ## large batch
      # file_path=ndp_csv_home+'new_'+model+'_ndp_batch_80-'+config+'-'+str(g)+'-'+str(g)+'-'+s+'.csv'
      # file_path_bw=ndp_csv_home+'new_'+model+'_ndp_batch_80-'+config+'-'+str(g)+'-'+str(g)+'-'+s+'-bw.csv'
      # batch_80 = setup_dataframe(pd.concat([pd.read_csv(file_path), pd.read_csv(file_path_bw)]))
      # batch_80['BATCH SIZE'] = 'Batch 80'
      # batch_80['SYNC'] = 'BN'
      # batch_80['GPUS'] = '4_GPU'
      # batch_80['CONFIG'] = 'NDPX_baseline_64'
      # batch_80['CYCLE'] = pd.to_numeric(batch_80['CYCLE'])
      # # batch_80.to_csv('batch_80.csv')
      # df = pd.concat([df, batch_80])
      ## large batch

      grouped = df.groupby(['CONFIG','GPUS','SYNC','NAME']).sum()[[ 'CYCLE']]
      grouped.to_csv('temp1-1.csv')
      grouped['MODEL'] = model
      grouped['MODEL'] = grouped['MODEL'].replace('new_', '', regex=True) \
         .replace('resnet', 'ResNet-', regex=True) \
         .replace('mobilenetv2', 'MobileNetv2') \
         .replace('vgg16', 'VGG-16')
      grouped.to_csv('temp2.csv')
      grouped['BATCH SIZE'] = 'Batch '+str(b)
      grouped.to_csv('./'+model+'/total_value'+str(b)+'.csv')
      normalized = grouped
      normalized['CYCLE'] = grouped['CYCLE'] / baseline_runtime
      normalized.to_csv('./'+model+'/total_normalized'+str(b)+'.csv')
# Out:
# /home/shared/CXL_memory_buffer/BASELINE_ISCA/csv_files/resnet18_baseline_batch_64_l1hit-NDPX_baseline_64_l1hit.csv
# /home/shared/CXL_memory_buffer/NDP_ISCA/csv_files/resnet18_ndp_batch_64_opt-GPU-NDP_1GH_NDP-1-1-nosync-bw.csv
# /home/shared/CXL_memory_buffer/BASELINE_ISCA/csv_files/resnet50_baseline_batch_64_l1hit-NDPX_baseline_64_l1hit.csv
# /home/shared/CXL_memory_buffer/NDP_ISCA/csv_files/resnet50_ndp_batch_64_opt-GPU-NDP_1GH_NDP-1-1-nosync-bw.csv
# /home/shared/CXL_memory_buffer/BASELINE_ISCA/csv_files/mobilenetv2_baseline_batch_64_l1hit-NDPX_baseline_64_l1hit.csv
# /home/shared/CXL_memory_buffer/NDP_ISCA/csv_files/mobilenetv2_ndp_batch_64_opt-GPU-NDP_1GH_NDP-1-1-nosync-bw.csv
# /home/shared/CXL_memory_buffer/BASELINE_ISCA/csv_files/vgg16_baseline_batch_32_l1hit-NDPX_baseline_64_l1hit.csv
# /home/shared/CXL_memory_buffer/NDP_ISCA/csv_files/vgg16_ndp_batch_32_opt-GPU-NDP_1GH_NDP-1-1-nosync-bw.csv

# %%
fw_models = ['resnet18', 'mobilenetv2', 'vgg16', 'resnet50']
bw_models = ['resnet18', 'mobilenetv2', 'vgg16', 'resnet50']
total_models = ['resnet18', 'mobilenetv2', 'vgg16', 'resnet50']
# fw_models = ['resnet18', 'mobilenetv2']
# bw_models = ['resnet18', 'mobilenetv2']
# total_models = ['resnet18', 'mobilenetv2']
# fw_models = ['resnet50']
# bw_models = ['resnet50']
# total_models = ['resnet50']
# fw_models = ['vgg16']
# bw_models = ['vgg16']
# total_models = ['vgg16']
# fw_models = ['resnet18', 'mobilenetv2', 'vgg16']
# bw_models = ['resnet18', 'mobilenetv2', 'vgg16']
# total_models = ['resnet18', 'mobilenetv2', 'vgg16']
batch_size = [64] # [16, 64]
# sync = ['BN', 'syncBN']
# gpus = ['1_GPU', '2_GPU', '4_GPU']

fw_files = []
bw_files = []
total_files = []

fw_raw_files = []
bw_raw_files = []
total_raw_files = []

for m in fw_models:
   for b in batch_size:
      if m == 'vgg16' and b == 64:
         b = 32
      fw_files.append('./'+m+'/normalized'+str(b)+'.csv')
      fw_raw_files.append('./'+m+'/value'+str(b)+'.csv')
for m in bw_models:
   for b in batch_size:
      if m == 'vgg16' and b == 64:
         b = 32
      bw_files.append('./'+m+'/normalized'+str(b)+'-bw.csv')
      bw_raw_files.append('./'+m+'/value'+str(b)+'-bw.csv')
for m in total_models:
   for b in batch_size:
      if m == 'vgg16' and b == 64:
         b = 32
      total_files.append('./'+m+'/total_normalized'+str(b)+'.csv')
      total_raw_files.append('./'+m+'/total_value'+str(b)+'.csv')

fw_results = pd.concat([pd.read_csv(i) for i in fw_files])
bw_results = pd.concat([pd.read_csv(i) for i in bw_files])
total_results = pd.concat([pd.read_csv(i) for i in total_files])

fw_raw_results = pd.concat([pd.read_csv(i) for i in fw_raw_files])
bw_raw_results = pd.concat([pd.read_csv(i) for i in bw_raw_files])
total_raw_results = pd.concat([pd.read_csv(i) for i in total_raw_files])

total_raw_results['CYCLE'] = pd.to_numeric(total_raw_results['CYCLE'])
total_raw_results_grouped = total_raw_results.groupby(['CONFIG','GPUS','SYNC','BATCH SIZE','MODEL'], as_index=False).sum()
# total_raw_results_grouped = total_raw_results.groupby(['CONFIG','GPUS','SYNC','BATCH SIZE','MODEL']).sum()[[ 'CYCLE']]
total_raw_results_grouped.to_csv('./total_raw_results_grouped.csv', index=False)




fw_results.to_csv('./forward_results.csv', index=False)
bw_results.to_csv('./backward_results.csv', index=False)
total_results.to_csv('./total_results.csv', index=False)

fw_raw_results.to_csv('./forward_raw_results.csv', index=False)
bw_raw_results.to_csv('./backward_raw_results.csv', index=False)
total_raw_results.to_csv('./total_raw_results.csv', index=False)

# %%
batch_size = [64] # [16,64]
# models = ['resnet18', 'mobilenetv2', 'vgg16']
models = ['resnet50']
# models = ['vgg16']
sync = ['nosync']
GPUs = [1]
# config = 'V100_downscaled_HBM2_PCI6x1_write_prio_debug'

communication_dict = {
   'resnet18-2-nosync': 2814170, 
   'resnet18-4-nosync': 3622957.6,
   'resnet18-8-nosync': 4043382.8,
   'resnet18-2-sync': 2814170 + 555200,
   'resnet18-4-sync': 3622957.6 + 943840,
   'resnet18-8-sync': 4043382.8 + 1887680,
   'resnet50-2-nosync': 5453729.6,
   'resnet50-4-nosync': 7215795.6,
   'resnet50-8-nosync': 8054841.6,
   'resnet50-2-sync': 5453729.6 + 1471280,
   'resnet50-4-sync': 7215795.6 + 2501176,
   'resnet50-8-sync': 8054841.6 + 5002352,
   'mobilenetv2-2-nosync': 905114.8,
   'mobilenetv2-4-nosync': 1135800.4,
   'mobilenetv2-8-nosync': 1562888,
   'mobilenetv2-2-sync': 905114.8 + 1443520,
   'mobilenetv2-4-sync': 1135800.4 + 2453984,
   'vgg16-2-nosync': 28906152,
   'vgg16-4-nosync': 39120444,
   'vgg16-8-nosync': 44746734,
   'vgg16-2-sync': 28906152 + 347880,
   'vgg16-4-sync': 39120444 + 591396
}



for model in models:
   for b in batch_size:
      if model == 'vgg16' and b == 64:
         b = 32
      file_paths = []
      baseline_home='/home/shared/CXL_memory_buffer/BASELINE_ISCA/csv_files/'
      baseline_path=baseline_home+model+'_baseline_batch_'+str(b)+'-NDPX_baseline_64.csv'
      baseline_bw_path=baseline_home+model+'_baseline_batch_'+str(b)+'-NDPX_baseline_64-bw.csv'
      file_paths.append(baseline_path)
      file_paths.append(baseline_bw_path)
      baseline0 = pd.read_csv(file_paths[0])
      baseline0['GPUS'] = '1_GPU'
      baseline0['CONFIG'] = 'BASELINE'
      baseline1 = pd.read_csv(file_paths[1])
      baseline1['GPUS'] = '1_GPU'
      baseline1['CONFIG'] = 'BASELINE'


      baseline_hlp_path=baseline_home+'xla_hlo/'+model+'_baseline_batch_'+str(b)+'.txt'
      df = setup_dataframe_baseline(baseline0, baseline_hlp_path)
      baseline_runtime = pd.to_numeric(df['CYCLE']).sum()
      # print(file_paths[2])
      # df = pd.concat([df, setup_dataframe_baseline(baseline2, baseline_hlp_path)])
      df['SYNC'] = 'BN'

      df.to_csv('temp.csv')
      original_df = df.copy()
      for g in GPUs:
         if g == 1:
            continue
         for s in sync:
            df_multi_GPU = original_df.copy()
            df_multi_GPU['GPUS'] = f'{g}_GPU'        
            df_multi_GPU['SYNC'] = 'BN' if s == 'nosync' else 'syncBN'
            communication_key = model+'-'+str(g)+'-'+s
            communication_overhead = communication_dict[communication_key]
            all_reduce = {'GPUS': str(g)+'_GPU', 'CONFIG': 'BASELINE', 'DIRECTION': 'backward', 'NAME': 'All-reduce', 'CYCLE': str(communication_overhead), 'SYNC': 'BN' if s == 'nosync' else 'syncBN'}
            df_multi_GPU = df_multi_GPU.append(all_reduce, ignore_index=True)
            df = pd.concat([df, df_multi_GPU])

      df['CYCLE'] = pd.to_numeric(df['CYCLE'])
      df.to_csv('temp1.csv')
      
      # ## large batch
      # file_path=ndp_csv_home+'new_'+model+'_ndp_batch_80-'+config+'-'+str(g)+'-'+str(g)+'-'+s+'.csv'
      # file_path_bw=ndp_csv_home+'new_'+model+'_ndp_batch_80-'+config+'-'+str(g)+'-'+str(g)+'-'+s+'-bw.csv'
      # batch_80 = setup_dataframe(pd.concat([pd.read_csv(file_path), pd.read_csv(file_path_bw)]))
      # batch_80['BATCH SIZE'] = 'Batch 80'
      # batch_80['SYNC'] = 'BN'
      # batch_80['GPUS'] = '4_GPU'
      # batch_80['CONFIG'] = 'NDPX_baseline_64'
      # batch_80['CYCLE'] = pd.to_numeric(batch_80['CYCLE'])
      # # batch_80.to_csv('batch_80.csv')
      # df = pd.concat([df, batch_80])
      ## large batch

      # grouped = df.groupby(['CONFIG','GPUS','SYNC','NAME']).sum()[[ 'CYCLE']]
      # grouped.to_csv('temp1-1.csv')
      # grouped['MODEL'] = model
      # grouped['MODEL'] = grouped['MODEL'].replace('new_', '', regex=True) \
      #    .replace('resnet', 'ResNet-', regex=True) \
      #    .replace('mobilenetv2', 'MobileNetv2') \
      #    .replace('vgg16', 'VGG-16')
      # grouped.to_csv('temp2.csv')
      # grouped['BATCH SIZE'] = 'Batch '+str(b)
      # grouped.to_csv('./'+model+'/total_value'+str(b)+'.csv')
      # normalized = grouped
      # normalized['CYCLE'] = grouped['CYCLE'] / baseline_runtime
      # normalized.to_csv('./'+model+'/total_normalized'+str(b)+'.csv')
      grouped = df.groupby(['CONFIG','GPUS','SYNC','NAME']).sum()
      grouped['MODEL'] = model
      grouped['MODEL'] = grouped['MODEL'].replace('new_', '', regex=True) \
         .replace('resnet', 'ResNet-', regex=True) \
         .replace('mobilenetv2', 'MobileNetv2') \
         .replace('vgg16', 'VGG-16')
      grouped['BATCH SIZE'] = 'Batch '+str(b)
      grouped.to_csv('temp2.csv')

# %%
baseline_home='/home/shared/CXL_memory_buffer/BASELINE_ISCA/csv_files/'
fw = 'bert_base_seq512_baseline_batch_16-V100_downscaled_HBM2_PCI6x1.csv'
bw = 'bert_base_seq512_baseline_batch_16-V100_downscaled_HBM2_PCI6x1-bw.csv'

fw_csv = pd.read_csv(baseline_home+'/'+fw)
bw_csv = pd.read_csv(baseline_home+'/'+bw)

fw_runtime = pd.to_numeric(fw_csv['CYCLE']).sum()
bw_runtime = pd.to_numeric(bw_csv['CYCLE']).sum()

print(f'Forward total cycle: {fw_runtime}')
print(f'Backward total cycle: {bw_runtime}')
# Out:
# Forward total cycle: 28096415
# Backward total cycle: 55316632

# %%
batch_size = [16, 64]
models = ['resnet18']
sync = ['sync', 'nosync']
GPUs = [1,2,4]

for model in models:
   for b in batch_size:
      if model == 'vgg16' and b == 64:
         b = 32
      file_paths = []
      baseline_home='/home/shared/CXL_memory_buffer/BASELINE_ISCA/csv_files/'
      baseline_path=baseline_home+model+'_baseline_batch_'+str(b)+'-V100_downscaled_HBM2_PCI6x1_write_prio_debug.csv'
      file_paths.append(baseline_path)
      # file_paths.append(baseline2xmem_path)
      for GPU in GPUs:
         for s in sync:
            if GPU == 1 and s == 'sync':
               continue
            ndp_csv_home='/home/shared/CXL_memory_buffer/NDP_ISCA/csv_files/'
            file_path=ndp_csv_home+model+'_ndp_batch_'+str(b)+'-V100_downscaled_HBM2_PCI6x1_write_prio_debug-'+str(GPU)+'-'+s+'.csv'
            file_paths.append(file_path)
      # print(file_paths)
      # kernel_name_path = 'kernel_name/'+model+'_'+str(b)
      # kernel_name = open(kernel_name_path, 'r')
      # kernel_names = kernel_name.readlines()
      # kernel_name.close()
      # kernel_names = kernel_names[1:]
      # kernel_names = [name.replace("\n", "") for name in kernel_names]

      baseline0 = pd.read_csv(file_paths[0])
      baseline0['GPUS'] = '1_GPU'
      # baseline0['NAME'] = kernel_names
      baseline0['CONFIG'] = 'BASELINE'

      print('file_paths:',file_paths)
      ndpx = pd.read_csv(file_paths[1])
      if 'nosync' in file_paths[1]:
         ndpx['SYNC'] ='BN'
      else:
         ndpx['SYNC'] = 'syncBN'
      ndpx['GPUS'] = file_paths[1].split('-')[-2]+'_GPU'
      for ndp_csv in file_paths[2:]:
         # print(ndp_csv)
         temp = pd.read_csv(ndp_csv)
         if 'nosync' in ndp_csv:
            temp['SYNC'] ='BN'
         else:
            temp['SYNC'] = 'syncBN'
         temp['GPUS'] = ndp_csv.split('-')[-2]+'_GPU'
         # print(ndp_csv)
         # print(ndp_csv.split('-')[-2])
         ndpx = pd.concat([ndpx, temp])
      # ndpx.to_csv('./'+model+'/ndpx'+str(b)+'.csv')

      df = setup_dataframe_baseline(baseline0.loc[baseline0['DIRECTION'] =='forward'])

      baseline_runtime = pd.to_numeric(df['CYCLE']).sum()

      # df = pd.concat([df, setup_dataframe(baseline1.loc[baseline1['DIRECTION'] == 'forward'])])
      df['SYNC'] = 'BN'
      df = pd.concat([df, setup_dataframe(ndpx.loc[ndpx['DIRECTION'] == 'forward'])])

      df['CYCLE'] = pd.to_numeric(df['CYCLE'])
      grouped = df.groupby(['CONFIG','GPUS','SYNC','NAME']).sum()[[ 'CYCLE']]

      grouped['BATCH SIZE'] = 'Batch '+str(b)
      grouped['DIRECTION'] = 'Forward'
      grouped['MODEL'] = model
      grouped.to_csv('./'+model+'/value'+str(b)+'.csv')
      normalized = grouped
      normalized['CYCLE'] = grouped['CYCLE'] / baseline_runtime
      normalized.to_csv('./'+model+'/normalized'+str(b)+'.csv')
# Out:
# file_paths: ['/home/shared/CXL_memory_buffer/BASELINE_ISCA/csv_files/resnet18_baseline_batch_16-V100_downscaled_HBM2_PCI6x1_write_prio_debug.csv', '/home/shared/CXL_memory_buffer/NDP_ISCA/csv_files/resnet18_ndp_batch_16-V100_downscaled_HBM2_PCI6x1_write_prio_debug-1-nosync.csv', '/home/shared/CXL_memory_buffer/NDP_ISCA/csv_files/resnet18_ndp_batch_16-V100_downscaled_HBM2_PCI6x1_write_prio_debug-2-sync.csv', '/home/shared/CXL_memory_buffer/NDP_ISCA/csv_files/resnet18_ndp_batch_16-V100_downscaled_HBM2_PCI6x1_write_prio_debug-2-nosync.csv', '/home/shared/CXL_memory_buffer/NDP_ISCA/csv_files/resnet18_ndp_batch_16-V100_downscaled_HBM2_PCI6x1_write_prio_debug-4-sync.csv', '/home/shared/CXL_memory_buffer/NDP_ISCA/csv_files/resnet18_ndp_batch_16-V100_downscaled_HBM2_PCI6x1_write_prio_debug-4-nosync.csv']
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ...

# %%
batch_size = [16, 64] # [16,64]
models = ['resnet18', 'resnet50']
# models = ['resnet18']
sync = ['sync', 'nosync']
GPUs = [4, 8]
config = 'V100_downscaled_HBM2_PCI6x1_write_prio_debug'

communication_dict = {
   'resnet18-2-nosync': 2814170, 
   'resnet18-4-nosync': 3622957.6,
   'resnet18-8-nosync': 4043382.8,
   'resnet18-2-sync': 2814170 + 555200,
   'resnet18-4-sync': 3622957.6 + 943840,
   'resnet18-8-sync': 4043382.8 + 1887680,
   'resnet50-2-nosync': 5453729.6,
   'resnet50-4-nosync': 7215795.6,
   'resnet50-8-nosync': 8054841.6,
   'resnet50-2-sync': 5453729.6 + 1471280,
   'resnet50-4-sync': 7215795.6 + 2501176,
   'resnet50-8-sync': 8054841.6 + 5002352,
   'mobilenetv2-2-nosync': 905114.8,
   'mobilenetv2-4-nosync': 1135800.4,
   'mobilenetv2-2-sync': 905114.8 + 1443520,
   'mobilenetv2-4-sync': 1135800.4 + 2453984,
   'vgg16-2-nosync': 28906152,
   'vgg16-4-nosync': 39120444,
   'vgg16-2-sync': 28906152 + 347880,
   'vgg16-4-sync': 39120444 + 591396
}



for model in models:
   for b in batch_size:
      if model == 'resnet50' and b == 64:
         continue
      if model == 'vgg16' and b == 64:
         b = 32
      file_paths = []
      baseline_home='/home/shared/CXL_memory_buffer/BASELINE_ISCA/csv_files/'
      baseline_path=baseline_home+model+'_baseline_batch_'+str(b)+'-V100_downscaled_HBM2_PCI6x1_write_prio_debug.csv'
      baseline_bw_path=baseline_home+model+'_baseline_batch_'+str(b)+'-V100_downscaled_HBM2_PCI6x1_write_prio_debug-bw.csv'
      file_paths.append(baseline_path)
      file_paths.append(baseline_bw_path)
      baseline_path=baseline_home+model+'_baseline_batch_'+str(b)+'-V100_downscaled_HBM2_PCI6x1_write_prio_debug_additional_sm.csv'
      baseline_bw_path=baseline_home+model+'_baseline_batch_'+str(b)+'-V100_downscaled_HBM2_PCI6x1_write_prio_debug_additional_sm-bw.csv'
      file_paths.append(baseline_path)
      file_paths.append(baseline_bw_path)
      baseline_path=baseline_home+model+'_baseline_batch_'+str(b)+'-V100_downscaled_HBM2_PCI6x1_write_prio_debug_additional_mem.csv'
      baseline_bw_path=baseline_home+model+'_baseline_batch_'+str(b)+'-V100_downscaled_HBM2_PCI6x1_write_prio_debug_additional_mem-bw.csv'
      file_paths.append(baseline_path)
      file_paths.append(baseline_bw_path)
      baseline_path=baseline_home+model+'_baseline_batch_'+str(b)+'-V100_downscaled_HBM2_PCI6x1_write_prio_debug_additional_hw.csv'
      baseline_bw_path=baseline_home+model+'_baseline_batch_'+str(b)+'-V100_downscaled_HBM2_PCI6x1_write_prio_debug_additional_hw-bw.csv'
      file_paths.append(baseline_path)
      file_paths.append(baseline_bw_path)
      # file_paths.append(baseline2xmem_path)
      for GPU in GPUs:
         for s in sync:
            if GPU == 1 and s == 'sync':
               continue
            temp = 1
            if GPU == 8:
               temp = 8
            ndp_csv_home='/home/shared/CXL_memory_buffer/NDP_ISCA/csv_files/'
            file_path=ndp_csv_home+model+'_ndp_batch_'+str(b)+'-'+config+'-'+str(GPU)+'-'+str(temp)+'-'+s+'.csv'
            file_path_bw=ndp_csv_home+model+'_ndp_batch_'+str(b)+'-'+config+'-'+str(GPU)+'-'+str(temp)+'-'+s+'-bw.csv'
            # file_path=ndp_csv_home+model+'_ndp_batch_'+str(b)+'-'+config+'-'+str(GPU)+'-'+s+'.csv'
            # file_path_bw=ndp_csv_home+model+'_ndp_batch_'+str(b)+'-'+config+'-'+str(GPU)+'-'+s+'-bw.csv'
            file_paths.append(file_path)
            file_paths.append(file_path_bw)

      baseline0 = pd.read_csv(file_paths[0])
      baseline0['GPUS'] = '1_GPU'
      baseline0['CONFIG'] = 'BASELINE'
      baseline1 = pd.read_csv(file_paths[1])
      baseline1['GPUS'] = '1_GPU'
      baseline1['CONFIG'] = 'BASELINE'

      baseline2 = pd.read_csv(file_paths[2])
      baseline2['GPUS'] = '1_GPU'
      baseline2['CONFIG'] = 'BASELINE_sm'
      baseline3 = pd.read_csv(file_paths[3])
      baseline3['GPUS'] = '1_GPU'
      baseline3['CONFIG'] = 'BASELINE_sm'

      baseline4 = pd.read_csv(file_paths[4])
      baseline4['GPUS'] = '1_GPU'
      baseline4['CONFIG'] = 'BASELINE_mem'
      baseline5 = pd.read_csv(file_paths[5])
      baseline5['GPUS'] = '1_GPU'
      baseline5['CONFIG'] = 'BASELINE_mem'

      baseline6 = pd.read_csv(file_paths[6])
      baseline6['GPUS'] = '1_GPU'
      baseline6['CONFIG'] = 'BASELINE_both'
      baseline7 = pd.read_csv(file_paths[7])
      baseline7['GPUS'] = '1_GPU'
      baseline7['CONFIG'] = 'BASELINE_both'

      # print('file_paths:',file_paths)
      ndpx = pd.read_csv(file_paths[8])
      if 'nosync' in file_paths[8]:
         ndpx['SYNC'] ='BN'
      else:
         ndpx['SYNC'] = 'syncBN'
      ndpx['GPUS'] = file_paths[8].split('-')[-3]+'_GPU'
      # ndpx['GPUS'] = file_paths[8].split('-')[-2]+'_GPU'
      for ndp_csv in file_paths[9:]:
         # print(ndp_csv)
         temp = pd.read_csv(ndp_csv)
         if 'nosync' in ndp_csv:
            temp['SYNC'] ='BN'
         else:
            temp['SYNC'] = 'syncBN'
         if 'bw' in ndp_csv.split('-')[-1]:
            print(ndp_csv)
            temp['GPUS'] = ndp_csv.split('-')[-4]+'_GPU'
            # temp['GPUS'] = ndp_csv.split('-')[-3]+'_GPU'
         else:
            temp['GPUS'] = ndp_csv.split('-')[-3]+'_GPU'
            # temp['GPUS'] = ndp_csv.split('-')[-2]+'_GPU'
         # print(ndp_csv)
         # print(ndp_csv.split('-')[-2])
         ndpx = pd.concat([ndpx, temp])
      # ndpx.to_csv('./'+model+'/ndpx'+str(b)+'.csv')

      # df = setup_dataframe_baseline(baseline0.loc[baseline0['DIRECTION'] =='forward'])
      baseline_hlp_path=baseline_home+'xla_hlo/'+model+'_baseline_batch_'+str(b)+'.txt'
      df = setup_dataframe_baseline(pd.concat([baseline0, baseline1]), baseline_hlp_path)

      # df = df.loc[df['DIRECTION'] == 'forward']
      baseline_runtime = pd.to_numeric(df['CYCLE']).sum()
      df = pd.concat([df, setup_dataframe_baseline(pd.concat([baseline2, baseline3, baseline4, baseline5, baseline6, baseline7]), baseline_hlp_path)])

      # df = pd.concat([df, setup_dataframe(baseline1.loc[baseline1['DIRECTION'] == 'forward'])])
      # df = df.loc[df['DIRECTION'] == 'forward']
      df['SYNC'] = 'BN'

      original_df = df.copy()
      for g in GPUs:
         if g == 1:
            continue
         for s in sync:
            communication_key = model+'-'+str(g)+'-'+s
            communication_overhead = communication_dict[communication_key]
            new_baseline = original_df.copy()
            new_baseline['GPUS'] = str(g)+'_GPU'
            configs = ['BASELINE', 'BASELINE_sm', 'BASELINE_mem', 'BASELINE_both']
            if s == 'sync':
               s = 'syncBN'
            else:
               s = 'BN'
            new_baseline['SYNC'] = s
            for c in configs:
               all_reduce = {'GPUS': str(g)+'_GPU', 'CONFIG': c, 'DIRECTION': 'backward', 'NAME': 'All-reduce', 'CYCLE': str(communication_overhead), 'SYNC': s}
               new_baseline = new_baseline.append(all_reduce, ignore_index=True)
            df = pd.concat([df, new_baseline])
         # df.to_csv('temp.csv')
         # assert(False)

         

      df = pd.concat([df, setup_dataframe(ndpx)])
      # df = df.loc[df['DIRECTION'] == 'forward']
      df['CYCLE'] = pd.to_numeric(df['CYCLE'])
      grouped = df.groupby(['CONFIG','GPUS','SYNC','NAME']).sum()[[ 'CYCLE']]

      grouped['BATCH SIZE'] = 'Batch '+str(b)
      # grouped['DIRECTION'] = 'Forward'
      grouped['MODEL'] = model
      grouped.to_csv('./'+model+'/total_value'+str(b)+'.csv')
      normalized = grouped
      normalized['CYCLE'] = grouped['CYCLE'] / baseline_runtime
      normalized.to_csv('./'+model+'/total_normalized'+str(b)+'.csv')
# Out:
# file_paths: ['/home/shared/CXL_memory_buffer/BASELINE_ISCA/csv_files/resnet18_baseline_batch_16-V100_downscaled_HBM2_PCI6x1_write_prio_debug-bw.csv', '/home/shared/CXL_memory_buffer/NDP_ISCA/csv_files/resnet18_ndp_batch_16-V100_downscaled_HBM2_PCI6x1_write_prio_debug-1-nosync-bw.csv', '/home/shared/CXL_memory_buffer/NDP_ISCA/csv_files/resnet18_ndp_batch_16-V100_downscaled_HBM2_PCI6x1_write_prio_debug-2-sync-bw.csv', '/home/shared/CXL_memory_buffer/NDP_ISCA/csv_files/resnet18_ndp_batch_16-V100_downscaled_HBM2_PCI6x1_write_prio_debug-2-nosync-bw.csv', '/home/shared/CXL_memory_buffer/NDP_ISCA/csv_files/resnet18_ndp_batch_16-V100_downscaled_HBM2_PCI6x1_write_prio_debug-4-sync-bw.csv', '/home/shared/CXL_memory_buffer/NDP_ISCA/csv_files/resnet18_ndp_batch_16-V100_downscaled_HBM2_PCI6x1_write_prio_debug-4-nosync-bw.csv']
# ...

# %%
# fw_models = ['mobilenetv2', 'vgg16']
fw_models = ['resnet18']
bw_models = ['resnet18']

batch_size = [16, 64]

fw_files = []
bw_files = []

for m in fw_models:
   for b in batch_size:
      if m == 'vgg16' and b == 64:
         b = 32
      fw_files.append('./'+m+'/normalized'+str(b)+'.csv')
for m in bw_models:
   for b in batch_size:
      if m == 'vgg16' and b == 64:
         b = 32
      bw_files.append('./'+m+'/normalized'+str(b)+'-bw.csv')

fw_results = pd.concat([pd.read_csv(i) for i in fw_files])
bw_results = pd.concat([pd.read_csv(i) for i in bw_files])
total_results = pd.concat([fw_results, bw_results])

fw_results.to_csv('./forward_results.csv')
bw_results.to_csv('./backward_results.csv')
total_results.to_csv('./total_results.csv')

# %%
batch_size = [16]
models = ['bert']
sync = ['sync', 'nosync']
GPUs = [1]

for model in models:
   for b in batch_size:
      if model == 'vgg16' and b == 64:
         b = 32
      file_paths = []
      baseline_home='/home/shared/CXL_memory_buffer/BASELINE_ISCA/csv_files/'
      baseline_path=baseline_home+model+'_baseline_batch_'+str(b)+'-V100_downscaled_HBM2_PCI6x1.csv'
      file_paths.append(baseline_path)
      # file_paths.append(baseline2xmem_path)
      for GPU in GPUs:
         for s in sync:
            if GPU == 1 and s == 'sync':
               continue
            ndp_csv_home='/home/shared/CXL_memory_buffer/NDP_ISCA/csv_files/'
            file_path=ndp_csv_home+model+'_ndp_batch_'+str(b)+'-V100_downscaled_HBM2_PCI6x1_write_prio-'+str(GPU)+'-'+s+'.csv'
            file_paths.append(file_path)
      # print(file_paths)
      # kernel_name_path = 'kernel_name/'+model+'_'+str(b)
      # kernel_name = open(kernel_name_path, 'r')
      # kernel_names = kernel_name.readlines()
      # kernel_name.close()
      # kernel_names = kernel_names[1:]
      # kernel_names = [name.replace("\n", "") for name in kernel_names]

      baseline0 = pd.read_csv(file_paths[0])
      baseline0['GPUS'] = '1_GPU'
      # baseline0['NAME'] = kernel_names
      baseline0['CONFIG'] = 'BASELINE'

      print(baseline0)

      ndpx = baseline0
      ndpx['CONFIG'] = 'NDPX'
      modified_kernel = pd.read_csv(file_paths[1])
      ndp_kernels = ['8125', '8126', '8127', '8145', '8146', '8147', '8148', '8149', '8152', '8153', '8154', '8155', '8156', '8173', '8174', '8175', '8176', '8177', '8180', '8181', '8182', '8183', ]
      # for k in ndp_kernels:
      modified_kernel.loc[df['ID'] == ndp_kernels, 'CYCLE'] = '0'

      print(modified_kernel)

      print('file_paths:',file_paths)
      ndpx = pd.read_csv(file_paths[1])
      if 'nosync' in file_paths[1]:
         ndpx['SYNC'] ='BN'
      else:
         ndpx['SYNC'] = 'syncBN'
      ndpx['GPUS'] = file_paths[1].split('-')[-2]+'_GPU'

      df = setup_dataframe_baseline(baseline0.loc[baseline0['DIRECTION'] =='forward'])

      baseline_runtime = pd.to_numeric(df['CYCLE']).sum()

      # df = pd.concat([df, setup_dataframe(baseline1.loc[baseline1['DIRECTION'] == 'forward'])])
      df['SYNC'] = 'BN'
      df = pd.concat([df, setup_dataframe(ndpx.loc[ndpx['DIRECTION'] == 'forward'])])

      df['CYCLE'] = pd.to_numeric(df['CYCLE'])
      grouped = df.groupby(['CONFIG','GPUS','SYNC','NAME']).sum()[[ 'CYCLE']]

      grouped['BATCH SIZE'] = 'Batch '+str(b)
      grouped['DIRECTION'] = 'Forward'
      grouped['MODEL'] = model
      grouped.to_csv('./'+model+'/value'+str(b)+'.csv')
      normalized = grouped
      normalized['CYCLE'] = grouped['CYCLE'] / baseline_runtime
      normalized.to_csv('./'+model+'/normalized'+str(b)+'.csv')
# Out:
#       GPUS    CONFIG    ID DIRECTION  \
# 0    1_GPU  BASELINE  8095   forward
# 1    1_GPU  BASELINE  8096   forward
# 2    1_GPU  BASELINE  8097   forward
# 3    1_GPU  BASELINE  8098   forward
# 4    1_GPU  BASELINE  8099   forward
# ..     ...       ...   ...       ...
# 99   1_GPU  BASELINE  8194   forward
# 100  1_GPU  BASELINE  8195   forward
# 101  1_GPU  BASELINE  8196   forward
# 102  1_GPU  BASELINE  8197   forward
# 103  1_GPU  BASELINE  8198   forward
#
#                                             NAME  CYCLE
# 0                                     fusion_281   6754
# 1                                     fusion_195   6758
# 2                                     fusion_279   8027
# 3                                     fusion_196   7647
# 4                                     fusion_280   7805
# ..                                           ...    ...
# 99                                     fusion_24   9077
# 100                                        pad_6   6359
# ...

# %%
# file_path0='../mobilenet_v2_b32-V100_downscaled_Baseline_HBM2.csv'
# file_path1='../mobilenet_v2_b32-V100_downscaled_Baseline_2_HBM2.csv'
# file_path2='../mobilenet_v2_b32-V100_downscaled_Baseline_HBM2_no_tlb.csv'
# file_path3='../mobilenet_v2_b32-V100_downscaled_Baseline_2_HBM2_no_tlb.csv'
# file_path4='../mobilenet_v2_b32-V100_downscaled_Baseline_HBM2_no_tlb_l1_debug.csv'
# file_path5='../mobilenet_v2_b32-V100_downscaled_Baseline_2_HBM2_no_tlb_l1_debug.csv'
# file_path6='/home/shared/CXL_memory_buffer/NDP_TRACES/csv_files/mobilenetv2_ndp_batch_32-V100_downscaled_HBM2_PCI6x1.csv'
# file_path7='/home/shared/CXL_memory_buffer/NDP_TRACES/csv_files/mobilenetv2_ndp_batch_32-V100_downscaled_GDDR5_PCI6x1.csv'
# file_path8='/home/shared/CXL_memory_buffer/NDP_TRACES/csv_files/mobilenetv2_ndp_batch_32-V100_downscaled_GDDR5_PCI6x1_no_tlb.csv'
# file_path9='/home/shared/CXL_memory_buffer/NDP_TRACES/csv_files/mobilenetv2_ndp_batch_32-V100_downscaled_GDDR5_PCI6x1_no_tlb_l1_debug.csv'
# baseline0 = pd.read_csv(file_path0)
# baseline1 = pd.read_csv(file_path1)
# baseline2 = pd.read_csv(file_path2)
# baseline3 = pd.read_csv(file_path3)
# baseline4 = pd.read_csv(file_path4)
# baseline5 = pd.read_csv(file_path5)


# kernel_name_path = 'kernel_name/mobilenet_32'
# kernel_name = open(kernel_name_path, 'r')
# kernel_names = kernel_name.readlines()
# kernel_name.close()
# kernel_names = kernel_names[1:]
# kernel_names = [name.replace("\n", "") for name in kernel_names]

# baseline0 = pd.read_csv(file_path0)
# baseline0['NAME'] = kernel_names
# baseline1 = pd.read_csv(file_path1)
# baseline1['NAME'] = kernel_names
# baseline2 = pd.read_csv(file_path2)
# baseline2['NAME'] = kernel_names
# baseline3 = pd.read_csv(file_path3)
# baseline3['NAME'] = kernel_names
# baseline4 = pd.read_csv(file_path4)
# baseline4['NAME'] = kernel_names
# baseline5 = pd.read_csv(file_path5)
# baseline5['NAME'] = kernel_names


# # test = setup_dataframe(pd.read_csv(file_path3))
# # test.to_csv('./mobilenet/test.csv')

# # ndpx1 = pd.concat([pd.read_csv(file_path2)])
# # ndpx1 = pd.concat([pd.read_csv(file_path2), pd.read_csv(file_path3)])
# ndpx1 = pd.concat([pd.read_csv(file_path6), pd.read_csv(file_path7)\
#    , pd.read_csv(file_path8), pd.read_csv(file_path9)])

# df = setup_dataframe(baseline0.loc[baseline0['DIRECTION'] =='forward'])

# baseline_runtime = pd.to_numeric(df['CYCLE']).sum()

# df = pd.concat([df, setup_dataframe(baseline1.loc[baseline1['DIRECTION'] == 'forward']), setup_dataframe(baseline2.loc[baseline2['DIRECTION'] == 'forward'])\
#    , setup_dataframe(baseline3.loc[baseline3['DIRECTION'] == 'forward']), setup_dataframe(baseline4.loc[baseline4['DIRECTION'] == 'forward']), setup_dataframe(baseline5.loc[baseline5['DIRECTION'] == 'forward'])])
# df = pd.concat([df, setup_dataframe(ndpx1.loc[ndpx1['DIRECTION'] == 'forward'])])


# df['CYCLE'] = pd.to_numeric(df['CYCLE'])
# grouped = df.groupby(['CONFIG','NAME']).sum()[[ 'CYCLE']]

# grouped.to_csv('./mobilenet/value.csv')
# normalized = grouped
# normalized['CYCLE'] = grouped['CYCLE'] / baseline_runtime
# normalized.to_csv('./mobilenet/normalized.csv')

# %%
# batch_size = [16, 64]
# for b in batch_size:
#    # file_path0='../mobilenetv2_baseline_batch_'+str(b)+'-V100_downscaled_Baseline_HBM2.csv'
#    # file_path1='../mobilenetv2_baseline_batch_'+str(b)+'-V100_downscaled_Baseline_2_HBM2.csv'
#    # file_path2='../mobilenetv2_baseline_batch_'+str(b)+'-V100_downscaled_Baseline_HBM2_no_tlb.csv'
#    # file_path3='../mobilenetv2_baseline_batch_'+str(b)+'-V100_downscaled_Baseline_2_HBM2_no_tlb.csv'
#    file_path4='../mobilenetv2_baseline_batch_'+str(b)+'-V100_downscaled_Baseline_HBM2_no_tlb_l1_debug.csv'
#    file_path5='../mobilenetv2_baseline_batch_'+str(b)+'-V100_downscaled_Baseline_2_HBM2_no_tlb_l1_debug.csv'
#    # file_path6='/home/shared/CXL_memory_buffer/NDP_TRACES/csv_files/mobilenetv2_ndp_batch_'+str(b)+'-V100_downscaled_HBM2_PCI6x1.csv'
#    # file_path7='/home/shared/CXL_memory_buffer/NDP_TRACES/csv_files/mobilenetv2_ndp_batch_'+str(b)+'-V100_downscaled_GDDR5_PCI6x1.csv'
#    # file_path8='/home/shared/CXL_memory_buffer/NDP_TRACES/csv_files/mobilenetv2_ndp_batch_'+str(b)+'-V100_downscaled_GDDR5_PCI6x1_no_tlb.csv'
#    file_path9='/home/shared/CXL_memory_buffer/NDP_TRACES/csv_files/mobilenetv2_ndp_batch_'+str(b)+'-V100_downscaled_HBM2_PCI6x1_no_tlb_l1_debug.csv'
#    # baseline0 = pd.read_csv(file_path0)
#    # baseline1 = pd.read_csv(file_path1)
#    # baseline2 = pd.read_csv(file_path2)
#    # baseline3 = pd.read_csv(file_path3)
#    baseline4 = pd.read_csv(file_path4)
#    baseline5 = pd.read_csv(file_path5)

   
#    kernel_name_path = 'kernel_name/mobilenet_'+str(b)
#    kernel_name = open(kernel_name_path, 'r')
#    kernel_names = kernel_name.readlines()
#    kernel_name.close()
#    kernel_names = kernel_names[1:]
#    kernel_names = [name.replace("\n", "") for name in kernel_names]
   
#    # baseline0 = pd.read_csv(file_path0)
#    # baseline0['NAME'] = kernel_names
#    # baseline1 = pd.read_csv(file_path1)
#    # baseline1['NAME'] = kernel_names
#    # baseline2 = pd.read_csv(file_path2)
#    # baseline2['NAME'] = kernel_names
#    # baseline3 = pd.read_csv(file_path3)
#    # baseline3['NAME'] = kernel_names
#    baseline4 = pd.read_csv(file_path4)
#    baseline4['NAME'] = kernel_names
#    baseline5 = pd.read_csv(file_path5)
#    baseline5['NAME'] = kernel_names

#    # ndpx1 = pd.concat([pd.read_csv(file_path2)])
#    # ndpx1 = pd.concat([pd.read_csv(file_path2), pd.read_csv(file_path3)])
#    # ndpx1 = pd.concat([pd.read_csv(file_path6), pd.read_csv(file_path7)\
#    #    , pd.read_csv(file_path8), pd.read_csv(file_path9)])
#    ndpx1 = pd.read_csv(file_path9)

#    df = setup_dataframe(baseline4.loc[baseline4['DIRECTION'] =='forward'])

#    baseline_runtime = pd.to_numeric(df['CYCLE']).sum()

#    df = pd.concat([df, setup_dataframe(baseline5.loc[baseline5['DIRECTION'] == 'forward'])])
#    # , setup_dataframe(baseline2.loc[baseline2['DIRECTION'] == 'forward'])\
#    #    , setup_dataframe(baseline3.loc[baseline3['DIRECTION'] == 'forward']), setup_dataframe(baseline4.loc[baseline4['DIRECTION'] == 'forward']), setup_dataframe(baseline5.loc[baseline5['DIRECTION'] == 'forward'])])
#    df = pd.concat([df, setup_dataframe(ndpx1.loc[ndpx1['DIRECTION'] == 'forward'])])

#    df['CYCLE'] = pd.to_numeric(df['CYCLE'])
#    grouped = df.groupby(['CONFIG','NAME']).sum()[[ 'CYCLE']]

#    grouped.to_csv('./mobilenet/value'+str(b)+'.csv')
#    normalized = grouped
#    normalized['CYCLE'] = grouped['CYCLE'] / baseline_runtime
#    normalized.to_csv('./mobilenet/normalized'+str(b)+'.csv')

# %%
# file_path0='../resnet18_b32-V100_downscaled_Baseline_HBM2.csv'
# file_path1='../resnet18_b32-V100_downscaled_Baseline_2_HBM2.csv'
# file_path2='../resnet18_b32-V100_downscaled_Baseline_HBM2_no_tlb.csv'
# file_path3='../resnet18_b32-V100_downscaled_Baseline_2_HBM2_no_tlb.csv'
# file_path4='../resnet18_b32-V100_downscaled_Baseline_HBM2_no_tlb_l1_debug.csv'
# file_path5='../resnet18_b32-V100_downscaled_Baseline_2_HBM2_no_tlb_l1_debug.csv'
# file_path6='/home/shared/CXL_memory_buffer/NDP_TRACES/csv_files/resnet18_ndp_batch_32-V100_downscaled_HBM2_PCI6x1.csv'
# file_path7='/home/shared/CXL_memory_buffer/NDP_TRACES/csv_files/resnet18_ndp_batch_32-V100_downscaled_GDDR5_PCI6x1.csv'
# file_path8='/home/shared/CXL_memory_buffer/NDP_TRACES/csv_files/resnet18_ndp_batch_32-V100_downscaled_GDDR5_PCI6x1_no_tlb.csv'
# file_path9='/home/shared/CXL_memory_buffer/NDP_TRACES/csv_files/resnet18_ndp_batch_32-V100_downscaled_GDDR5_PCI6x1_no_tlb_l1_debug.csv'


# kernel_name_path = 'kernel_name/resnet18_32'
# kernel_name = open(kernel_name_path, 'r')
# kernel_names = kernel_name.readlines()
# kernel_name.close()
# kernel_names = kernel_names[1:]
# kernel_names = [name.replace("\n", "") for name in kernel_names]

# baseline0 = pd.read_csv(file_path0)
# baseline0['NAME'] = kernel_names
# baseline1 = pd.read_csv(file_path1)
# baseline1['NAME'] = kernel_names
# baseline2 = pd.read_csv(file_path2)
# baseline2['NAME'] = kernel_names
# baseline3 = pd.read_csv(file_path3)
# baseline3['NAME'] = kernel_names
# baseline4 = pd.read_csv(file_path4)
# baseline4['NAME'] = kernel_names
# baseline5 = pd.read_csv(file_path5)
# baseline5['NAME'] = kernel_names

# # test = setup_dataframe(pd.read_csv(file_path2))
# # test.to_csv('./resnet18/test.csv')
# # ndpx1 = pd.concat([pd.read_csv(file_path2)])
# # ndpx1 = pd.concat([pd.read_csv(file_path2), pd.read_csv(file_path3)])
# ndpx1 = pd.concat([pd.read_csv(file_path6), pd.read_csv(file_path7)\
#    , pd.read_csv(file_path8), pd.read_csv(file_path9)])

# df = setup_dataframe(baseline0.loc[baseline0['DIRECTION'] =='forward'])

# baseline_runtime = pd.to_numeric(df['CYCLE']).sum()

# df = pd.concat([df, setup_dataframe(baseline1.loc[baseline1['DIRECTION'] == 'forward']), setup_dataframe(baseline2.loc[baseline2['DIRECTION'] == 'forward'])\
#    , setup_dataframe(baseline3.loc[baseline3['DIRECTION'] == 'forward']), setup_dataframe(baseline4.loc[baseline4['DIRECTION'] == 'forward']), setup_dataframe(baseline5.loc[baseline5['DIRECTION'] == 'forward'])])
# df = pd.concat([df, setup_dataframe(ndpx1.loc[ndpx1['DIRECTION'] == 'forward'])])

# df['CYCLE'] = pd.to_numeric(df['CYCLE'])
# grouped = df.groupby(['CONFIG','NAME']).sum()[[ 'CYCLE']]

# grouped.to_csv('./resnet18/value.csv')
# normalized = grouped
# normalized['CYCLE'] = grouped['CYCLE'] / baseline_runtime
# normalized.to_csv('./resnet18/normalized.csv')

# %%
# batch_size = [16, 64]
# for b in batch_size:
#    # file_path0='../resnet18_baseline_batch_'+str(b)+'-V100_downscaled_Baseline_HBM2.csv'
#    # file_path1='../resnet18_baseline_batch_'+str(b)+'-V100_downscaled_Baseline_2_HBM2.csv'
#    # file_path2='../resnet18_baseline_batch_'+str(b)+'-V100_downscaled_Baseline_HBM2_no_tlb.csv'
#    # file_path3='../resnet18_baseline_batch_'+str(b)+'-V100_downscaled_Baseline_2_HBM2_no_tlb.csv'
#    file_path4='../resnet18_baseline_batch_'+str(b)+'-V100_downscaled_Baseline_HBM2_no_tlb_l1_debug.csv'
#    file_path5='../resnet18_baseline_batch_'+str(b)+'-V100_downscaled_Baseline_2_HBM2_no_tlb_l1_debug.csv'
#    # file_path6='/home/shared/CXL_memory_buffer/NDP_TRACES/csv_files/resnet18_ndp_batch_'+str(b)+'-V100_downscaled_HBM2_PCI6x1.csv'
#    # file_path7='/home/shared/CXL_memory_buffer/NDP_TRACES/csv_files/resnet18_ndp_batch_'+str(b)+'-V100_downscaled_GDDR5_PCI6x1.csv'
#    # file_path8='/home/shared/CXL_memory_buffer/NDP_TRACES/csv_files/resnet18_ndp_batch_'+str(b)+'-V100_downscaled_GDDR5_PCI6x1_no_tlb.csv'
#    file_path9='/home/shared/CXL_memory_buffer/NDP_TRACES/csv_files/resnet18_ndp_batch_'+str(b)+'-V100_downscaled_HBM2_PCI6x1_no_tlb_l1_debug.csv'

#    kernel_name_path = 'kernel_name/resnet18_'+str(b)
#    kernel_name = open(kernel_name_path, 'r')
#    kernel_names = kernel_name.readlines()
#    kernel_name.close()
#    kernel_names = kernel_names[1:]
#    kernel_names = [name.replace("\n", "") for name in kernel_names]

#    # baseline0 = pd.read_csv(file_path0)
#    # baseline0['NAME'] = kernel_names
#    # baseline1 = pd.read_csv(file_path1)
#    # baseline1['NAME'] = kernel_names
#    # baseline2 = pd.read_csv(file_path2)
#    # baseline2['NAME'] = kernel_names
#    # baseline3 = pd.read_csv(file_path3)
#    # baseline3['NAME'] = kernel_names
#    baseline4 = pd.read_csv(file_path4)
#    baseline4['NAME'] = kernel_names
#    baseline5 = pd.read_csv(file_path5)
#    baseline5['NAME'] = kernel_names
#    # ndpx1 = pd.concat([pd.read_csv(file_path2)])
#    # ndpx1 = pd.concat([pd.read_csv(file_path2), pd.read_csv(file_path3)])
#    # ndpx1 = pd.concat([pd.read_csv(file_path6), pd.read_csv(file_path7)\
#    #    , pd.read_csv(file_path8), pd.read_csv(file_path9)])
#    ndpx1 = pd.read_csv(file_path9)

#    df = setup_dataframe(baseline4.loc[baseline4['DIRECTION'] =='forward'])

#    baseline_runtime = pd.to_numeric(df['CYCLE']).sum()

#    df = pd.concat([df, setup_dataframe(baseline5.loc[baseline5['DIRECTION'] == 'forward'])])
#    # , setup_dataframe(baseline2.loc[baseline2['DIRECTION'] == 'forward'])\
#    #    , setup_dataframe(baseline3.loc[baseline3['DIRECTION'] == 'forward']), setup_dataframe(baseline4.loc[baseline4['DIRECTION'] == 'forward']), setup_dataframe(baseline5.loc[baseline5['DIRECTION'] == 'forward'])])
#    df = pd.concat([df, setup_dataframe(ndpx1.loc[ndpx1['DIRECTION'] == 'forward'])])

#    df['CYCLE'] = pd.to_numeric(df['CYCLE'])
#    grouped = df.groupby(['CONFIG','NAME']).sum()[[ 'CYCLE']]

#    grouped.to_csv('./resnet18/value'+str(b)+'.csv')
#    normalized = grouped
#    normalized['CYCLE'] = grouped['CYCLE'] / baseline_runtime
#    normalized.to_csv('./resnet18/normalized'+str(b)+'.csv')

#    # if b == 16:   
#    #    file_path5='/home/shared/CXL_memory_buffer/NDP_TRACES/csv_files/resnet18_ndp_batch_'+str(b)+'-V100_downscaled_HBM2_PCI6x2.csv'
#    #    file_path7='/home/shared/CXL_memory_buffer/NDP_TRACES/csv_files/resnet18_ndp_batch_'+str(b)+'-V100_downscaled_HBM2_PCI6x2_2RF.csv'
#    #    setup_dataframe(pd.read_csv(file_path5)).to_csv('./test1.csv')
#    #    setup_dataframe(pd.read_csv(file_path7)).to_csv('./test2.csv')

# %%
# batch_size = [16, 32]
# for b in batch_size:   
#    # file_path0='../vgg16_baseline_batch_'+str(b)+'-V100_downscaled_Baseline_HBM2.csv'
#    # file_path1='../vgg16_baseline_batch_'+str(b)+'-V100_downscaled_Baseline_2_HBM2.csv'
#    # file_path2='../vgg16_baseline_batch_'+str(b)+'-V100_downscaled_Baseline_HBM2_no_tlb.csv'
#    # file_path3='../vgg16_baseline_batch_'+str(b)+'-V100_downscaled_Baseline_2_HBM2_no_tlb.csv'
#    file_path4='../vgg16_baseline_batch_'+str(b)+'-V100_downscaled_Baseline_HBM2_no_tlb_l1_debug.csv'
#    file_path5='../vgg16_baseline_batch_'+str(b)+'-V100_downscaled_Baseline_2_HBM2_no_tlb_l1_debug.csv'
#    # file_path6='/home/shared/CXL_memory_buffer/NDP_TRACES/csv_files/vgg16_ndp_batch_'+str(b)+'-V100_downscaled_HBM2_PCI6x1.csv'
#    # file_path7='/home/shared/CXL_memory_buffer/NDP_TRACES/csv_files/vgg16_ndp_batch_'+str(b)+'-V100_downscaled_GDDR5_PCI6x1.csv'
#    # file_path8='/home/shared/CXL_memory_buffer/NDP_TRACES/csv_files/vgg16_ndp_batch_'+str(b)+'-V100_downscaled_GDDR5_PCI6x1_no_tlb.csv'
#    file_path9='/home/shared/CXL_memory_buffer/NDP_TRACES/csv_files/vgg16_ndp_batch_'+str(b)+'-V100_downscaled_HBM2_PCI6x1_no_tlb_l1_debug.csv'

#    # file_path8='/home/shared/CXL_memory_buffer/NDP_TRACES/csv_files/resnet50_ndp_batch_32-V100_downscaled_HBM2_PCI6x1_1GHz_10ns.csv'
#    # baseline0 = pd.read_csv(file_path0)
#    # baseline1 = pd.read_csv(file_path1)
#    # baseline2 = pd.read_csv(file_path2)
#    # baseline3 = pd.read_csv(file_path3)
#    # baseline4 = pd.read_csv(file_path4)
#    # baseline5 = pd.read_csv(file_path5)
   
#    kernel_name_path = 'kernel_name/vgg_'+str(b)
#    name_and_block = pd.read_csv(kernel_name_path)   
#    # baseline0 = pd.read_csv(file_path0)
#    # baseline0['NAME'] = name_and_block['NAME']
#    # baseline0['BLOCK'] = name_and_block['BLOCK']

#    # baseline1 = pd.read_csv(file_path1)
#    # baseline1['NAME'] = name_and_block['NAME']
#    # baseline1['BLOCK'] = name_and_block['BLOCK']

#    # baseline2 = pd.read_csv(file_path2)
#    # baseline2['NAME'] = name_and_block['NAME']
#    # baseline2['BLOCK'] = name_and_block['BLOCK']

#    # baseline3 = pd.read_csv(file_path3)
#    # baseline3['NAME'] = name_and_block['NAME']
#    # baseline3['BLOCK'] = name_and_block['BLOCK']

#    baseline4 = pd.read_csv(file_path4)
#    baseline4['NAME'] = name_and_block['NAME']
#    baseline4['BLOCK'] = name_and_block['BLOCK']

#    baseline5 = pd.read_csv(file_path5)
#    baseline5['NAME'] = name_and_block['NAME']
#    baseline5['BLOCK'] = name_and_block['BLOCK']

   
#    kernel_name_path_ndp = 'kernel_name/vgg-ndp_'+str(b)
#    name_and_block_ndp = pd.read_csv(kernel_name_path_ndp)   

   
#    # ndp6 = pd.read_csv(file_path6)
#    # ndp6['BLOCK'] = name_and_block_ndp['BLOCK']
#    # ndp7 = pd.read_csv(file_path7)
#    # ndp7['BLOCK'] = name_and_block_ndp['BLOCK']
#    # ndp8 = pd.read_csv(file_path8)
#    # ndp8['BLOCK'] = name_and_block_ndp['BLOCK']
#    ndp9 = pd.read_csv(file_path9)
#    ndp9['BLOCK'] = name_and_block_ndp['BLOCK']

#    # ndpx1 = pd.concat([pd.read_csv(file_path2)])
#    # ndpx1 = pd.concat([pd.read_csv(file_path2), pd.read_csv(file_path3)])
#    ndpx1 = ndp9

#    df = setup_dataframe(baseline4.loc[baseline4['DIRECTION'] =='forward'])

#    baseline_runtime = pd.to_numeric(df['CYCLE']).sum()

#    df = pd.concat([df, setup_dataframe(baseline5.loc[baseline5['DIRECTION'] == 'forward'])])
#    # , setup_dataframe(baseline2.loc[baseline2['DIRECTION'] == 'forward'])\
#    #    , setup_dataframe(baseline3.loc[baseline3['DIRECTION'] == 'forward']), setup_dataframe(baseline4.loc[baseline4['DIRECTION'] == 'forward']), setup_dataframe(baseline5.loc[baseline5['DIRECTION'] == 'forward'])])
#    df = pd.concat([df, setup_dataframe(ndpx1.loc[ndpx1['DIRECTION'] == 'forward'])])

#    df['CYCLE'] = pd.to_numeric(df['CYCLE'])
#    grouped2 = df.groupby(['CONFIG','BLOCK','NAME']).sum()[[ 'CYCLE']]
#    grouped = df.groupby(['CONFIG','NAME']).sum()[[ 'CYCLE']]
#    grouped2.to_csv('./vgg/block-'+str(b)+'.csv')
   
#    grouped.to_csv('./vgg/value'+str(b)+'.csv')
#    normalized = grouped
#    normalized['CYCLE'] = grouped['CYCLE'] / baseline_runtime
#    normalized.to_csv('./vgg/normalized'+str(b)+'.csv')

# %%
# import pandas as pd

# batch_size = [16, 32]
# for b in batch_size:
#    # file_path0='../vgg16_baseline_batch_'+str(b)+'-V100_downscaled_Baseline_HBM2-bw.csv'
#    # file_path1='../vgg16_baseline_batch_'+str(b)+'-V100_downscaled_Baseline_2_HBM2-bw.csv'
#    # file_path2='../vgg16_baseline_batch_'+str(b)+'-V100_downscaled_Baseline_HBM2_no_tlb-bw.csv'
#    # file_path3='../vgg16_baseline_batch_'+str(b)+'-V100_downscaled_Baseline_2_HBM2_no_tlb-bw.csv'
#    file_path4='../vgg16_baseline_batch_'+str(b)+'-V100_downscaled_Baseline_HBM2_no_tlb_l1_debug-bw.csv'
#    file_path5='../vgg16_baseline_batch_'+str(b)+'-V100_downscaled_Baseline_2_HBM2_no_tlb_l1_debug-bw.csv'
#    # file_path6='/home/shared/CXL_memory_buffer/NDP_TRACES/csv_files/vgg16_ndp_batch_'+str(b)+'-V100_downscaled_HBM2_PCI6x1-bw.csv'
#    # file_path7='/home/shared/CXL_memory_buffer/NDP_TRACES/csv_files/vgg16_ndp_batch_'+str(b)+'-V100_downscaled_GDDR5_PCI6x1-bw.csv'
#    # file_path8='/home/shared/CXL_memory_buffer/NDP_TRACES/csv_files/vgg16_ndp_batch_'+str(b)+'-V100_downscaled_GDDR5_PCI6x1_no_tlb-bw.csv'
#    file_path9='/home/shared/CXL_memory_buffer/NDP_TRACES/csv_files/vgg16_ndp_batch_'+str(b)+'-V100_downscaled_HBM2_PCI6x1_no_tlb_l1_debug-bw.csv'
#    # file_path2='/home/shared/CXL_memory_buffer/NDP_TRACES/csv_files/vgg16_ndp_batch_'+str(b)+'-V100_downscaled_HBM2_PCI6x1_1GHz-bw.csv'
#    # file_path3='/home/shared/CXL_memory_buffer/NDP_TRACES/csv_files/vgg16_ndp_batch_'+str(b)+'-V100_downscaled_HBM2_PCI6x1-bw.csv'
#    # file_path4='/home/shared/CXL_memory_buffer/NDP_TRACES/csv_files/vgg16_ndp_batch_'+str(b)+'-V100_downscaled_HBM2_PCI6x2_1GHz-bw.csv'
#    # file_path5='/home/shared/CXL_memory_buffer/NDP_TRACES/csv_files/vgg16_ndp_batch_'+str(b)+'-V100_downscaled_HBM2_PCI6x2-bw.csv'

#    # baseline0 = pd.read_csv(file_path0)
#    # baseline1 = pd.read_csv(file_path1)
#    # baseline2 = pd.read_csv(file_path2)
#    # baseline3 = pd.read_csv(file_path3)
   
#    kernel_name_path = 'kernel_name/vgg-bw_'+str(b)
#    name_and_block = pd.read_csv(kernel_name_path)   
#    # baseline0 = pd.read_csv(file_path0)
#    # baseline0['NAME'] = name_and_block['NAME']
#    # baseline0['BLOCK'] = name_and_block['BLOCK']

#    # baseline1 = pd.read_csv(file_path1)
#    # baseline1['NAME'] = name_and_block['NAME']
#    # baseline1['BLOCK'] = name_and_block['BLOCK']

#    # baseline2 = pd.read_csv(file_path2)
#    # baseline2['NAME'] = name_and_block['NAME']
#    # baseline2['BLOCK'] = name_and_block['BLOCK']

#    # baseline3 = pd.read_csv(file_path3)
#    # baseline3['NAME'] = name_and_block['NAME']
#    # baseline3['BLOCK'] = name_and_block['BLOCK']

#    baseline4 = pd.read_csv(file_path4)
#    baseline4['NAME'] = name_and_block['NAME']
#    baseline4['BLOCK'] = name_and_block['BLOCK']

#    baseline5 = pd.read_csv(file_path5)
#    baseline5['NAME'] = name_and_block['NAME']
#    baseline5['BLOCK'] = name_and_block['BLOCK']
   
#    kernel_name_path_ndp = 'kernel_name/vgg-ndp-bw_'+str(b)
#    name_and_block_ndp = pd.read_csv(kernel_name_path_ndp)   

#    # ndp6 = pd.read_csv(file_path6)
#    # ndp6['BLOCK'] = name_and_block_ndp['BLOCK']
#    # ndp7 = pd.read_csv(file_path7)
#    # ndp7['BLOCK'] = name_and_block_ndp['BLOCK']
#    # ndp8 = pd.read_csv(file_path8)
#    # ndp8['BLOCK'] = name_and_block_ndp['BLOCK']
#    ndp9 = pd.read_csv(file_path9)
#    ndp9['BLOCK'] = name_and_block_ndp['BLOCK']

#    # ndpx1 = pd.concat([pd.read_csv(file_path2)])
#    # ndpx1 = pd.concat([pd.read_csv(file_path2), pd.read_csv(file_path3)])
#    ndpx1 = ndp9

#    df = setup_dataframe(baseline4.loc[baseline4['DIRECTION'] =='backward'])
#    if b == 16:
#       df.to_csv('./test1.csv')

#    baseline_runtime = pd.to_numeric(df['CYCLE']).sum()

#    df = pd.concat([df, setup_dataframe(baseline5.loc[baseline5['DIRECTION'] == 'backward'])])
#    # , setup_dataframe(baseline2.loc[baseline2['DIRECTION'] == 'backward'])\
#    #    , setup_dataframe(baseline3.loc[baseline3['DIRECTION'] == 'backward']), setup_dataframe(baseline4.loc[baseline4['DIRECTION'] == 'backward']), setup_dataframe(baseline5.loc[baseline5['DIRECTION'] == 'backward'])])
#    df = pd.concat([df, setup_dataframe(ndpx1.loc[ndpx1['DIRECTION'] == 'backward'])])

#    df['CYCLE'] = pd.to_numeric(df['CYCLE'])
#    grouped = df.groupby(['CONFIG','NAME']).sum()[[ 'CYCLE']]

#    grouped2 = df.groupby(['CONFIG','BLOCK','NAME']).sum()[[ 'CYCLE']]
#    grouped.to_csv('./vgg/value-'+str(b)+'-bw.csv')
#    grouped2.to_csv('./vgg/block-'+str(b)+'-bw.csv')
#    normalized = grouped
#    normalized['CYCLE'] = grouped['CYCLE'] / baseline_runtime
#    normalized.to_csv('./vgg/normalized-'+str(b)+'-bw.csv')


#    # if b == 16:   
#    #    file_path5='../vgg16_baseline_batch_'+str(b)+'-V100_downscaled_Baseline_HBM2-bw.csv'
#    #    # file_path7='/home/shared/CXL_memory_buffer/NDP_TRACES/csv_files/resnet18_ndp_batch_'+str(b)+'-V100_downscaled_HBM2_PCI6x2_2RF.csv'
#    #    setup_dataframe(pd.read_csv(file_path5)).to_csv('./test1.csv')
#    #    # setup_dataframe(pd.read_csv(file_path7)).to_csv('./test2.csv')
